# %% [markdown]
# # import

# %%
import math
import time
import json
import torch
import random
import pickle
import torch.nn as nn
import numpy as np
import pandas as pd
from functools import partial
import torch.optim as optim
from torch.utils import data
from torch.utils.data import DataLoader
from functools import partialmethod
from scipy.stats import truncnorm
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # DataLoader

# %%
Seq_Coding={'A':[1.,0.,0.,0.],'T':[0.,1.,0.,0.],'C':[0.,0.,1.,0.],'G':[0.,0.,0.,1.],'N':[0.25,0.25,0.25,0.25]}
class NanoDataset(data.Dataset):
    def __init__(self,use_path):
        self.use_path=use_path
        self.LEN=0
        self.f_dict={}
        with open(use_path+'/use_files.txt','r') as f:
            for line in f.readlines():
                f_name=line.strip()
                self.f_dict[f_name]={'len':0,'label':1,'cont':[]}
                if f_name[-4:]=='_neg':
                    self.f_dict[f_name]['label']=0
                with open(use_path+'/'+f_name+'.index') as f2:
                    for line2 in f2.readlines():
                        items2=line2.strip().split('\t')
                        self.f_dict[f_name]['cont'].append((int(items2[1]),int(items2[2])))
                self.f_dict[f_name]['len']=len(self.f_dict[f_name]['cont'])
                self.LEN+=self.f_dict[f_name]['len']
    def __getitem__(self,index):
        R_dict={'seq_feature':[],'seq_mask':[],'nano_feature':[],'nano_mask':[],'label':0}
        for key in self.f_dict:
            if index>=self.f_dict[key]['len']:
                index-=self.f_dict[key]['len']
                continue
            label=self.f_dict[key]['label']
            R_dict['label']=label
            seekit=self.f_dict[key]['cont'][index]
            with open(self.use_path+'/'+key+'.json') as f:
                f.seek(seekit[0],0)
                json_str=f.read(seekit[1]-seekit[0])
                Ls=json_str.strip().split('\n')
                for each in json.loads(Ls[0]):
                    R_dict['seq_feature'].append(Seq_Coding[each])
                    if each=='N':
                        R_dict['seq_mask'].append(0)
                    else:
                        R_dict['seq_mask'].append(1)

                for L in Ls[1:]:
                    L_data=json.loads(L)
                    t_feature=[]
                    t_mask=[]
                    for each in L_data:
                        if each[0]<0:
                            t_feature.append([0,0,0])
                            t_mask.append(0)
                        else:
                            t_feature.append(each)
                            t_mask.append(1)
                    R_dict['nano_mask'].append(t_mask)
                    R_dict['nano_feature'].append(t_feature)
            break
        for key2 in R_dict:
            R_dict[key2]=torch.tensor(R_dict[key2])
        return R_dict
    def __len__(self):
        return self.LEN

# %%
m5C_Nano_set=NanoDataset('./edata/DataSet/m5C')
len(m5C_Nano_set)
# Out:
# 5722

# %%
RELOAD=0
if RELOAD==1:
    m5C_Nano_set=NanoDataset('./edata/DataSet/m5C')
    train_size=int(len(m5C_Nano_set)*0.8)
    test_size=len(m5C_Nano_set)-train_size
    m5C_Nano_train_set,m5C_Nano_test_set=torch.utils.data.random_split(m5C_Nano_set,[train_size,test_size])
    with open('./edata/Save_DataSet/m5C_Nano_train_set.pkl','wb') as f:
        pickle.dump(m5C_Nano_train_set,f)
    with open('./edata/Save_DataSet/m5C_Nano_test_set.pkl','wb') as f:
        pickle.dump(m5C_Nano_test_set,f)
    m5C_Nano_train_loader=DataLoader(m5C_Nano_train_set,batch_size=5,shuffle=True)
    m5C_Nano_test_loader=DataLoader(m5C_Nano_test_set,batch_size=5,shuffle=True)

else:
    with open('./edata/Save_DataSet/m5C_Nano_train_set.pkl','rb') as f:
        m5C_Nano_train_set=pickle.load(f)
    with open('./edata/Save_DataSet/m5C_Nano_test_set.pkl','rb') as f:
        m5C_Nano_test_set=pickle.load(f)
    m5C_Nano_train_loader=DataLoader(m5C_Nano_train_set,batch_size=5,shuffle=True)
    m5C_Nano_test_loader=DataLoader(m5C_Nano_test_set,batch_size=5,shuffle=True)

# %% [markdown]
# # Tools for Model

# %%
def glorot_uniform_init_(weights):
    nn.init.xavier_uniform_(weights,gain=1)
def zero_init_(weights):
    with torch.no_grad():
        weights.fill_(0.0)
def permute_final_dims(tensor,inds):
    zero_index=-1*len(inds)
    first_inds=list(range(len(tensor.shape[:zero_index])))
    return tensor.permute(first_inds+[zero_index+i for i in inds])
def flatten_final_dims(t,no_dims):
    return t.reshape(t.shape[:-no_dims]+(-1,))
def relu_init_(weights,scale=2.0):
    shape=weights.shape
    _,f=shape
    scale=scale/max(1,f)
    a=-2
    b=2
    std=math.sqrt(scale)/truncnorm.std(a=a,b=b,loc=0,scale=1)
    size=1
    for n in shape:
        size=size*n
    samples=truncnorm.rvs(a=a,b=b,loc=0,scale=std,size=size)
    samples=np.reshape(samples,shape)
    with torch.no_grad():
        weights.copy_(torch.tensor(samples,device=weights.device))

class Dropout(nn.Module):
    def __init__(self,r,batch_dim):
        super(Dropout,self).__init__()
        self.r=r
        if type(batch_dim)==int:
            batch_dim=[batch_dim]
        self.batch_dim=batch_dim
        self.dropout=nn.Dropout(r)
    def forward(self,x):
        shape=list(x.shape)
        if self.batch_dim is not None:
            for bd in self.batch_dim:
                shape[bd]=1
        mask=x.new_ones(shape)
        mask=self.dropout(mask)
        x*=mask
        return x
class DropoutRowwise(Dropout):
    __init__=partialmethod(Dropout.__init__,batch_dim=-3)
class DropoutColwise(Dropout):
    __init__=partialmethod(Dropout.__init__,batch_dim=-2)

# %%
class Linear(nn.Linear):
    def __init__(self,in_dim,out_dim,bias=True,init="zero"):
        super(Linear, self).__init__(in_dim, out_dim, bias=bias)
        if bias:
            with torch.no_grad():
                self.bias.fill_(0)
        with torch.no_grad():
            if init=="zero":
                zero_init_(self.weight)
            elif init=="glorot":
                glorot_uniform_init_(self.weight)
            elif init=="gating":
                zero_init_(self.weight)
                if bias:
                    self.bias.fill_(1.0)
class LayerNorm(nn.Module):
    def __init__(self,c_in,eps=1e-5):
        super(LayerNorm, self).__init__()
        self.c_in=(c_in,)
        self.eps=eps
        self.weight=nn.Parameter(torch.ones(c_in))
        self.bias=nn.Parameter(torch.zeros(c_in))
    def forward(self,x): 
        out=nn.functional.layer_norm(x,self.c_in,self.weight,self.bias,self.eps)
        return out

# %%
class LinearEmbedder(nn.Module):
    def __init__(self,c_in,c_out):
        super(LinearEmbedder,self).__init__()
        self.c_in=c_in
        self.c_out=c_out
        self.linear_1=nn.Linear(c_in,c_out)
        self.relu=nn.ReLU()
        self.linear_2=nn.Linear(c_out,c_out)
    def forward(self,x):
        x=self.linear_1(x)
        x=self.relu(x)
        x=self.linear_2(x)
        return x

# %% [markdown]
# # Model Component

# %%
MAX_SEQ_LEN=50
def precompute_freqs_cis(dim,seq_len,theta=10000.0):
    freqs=1.0/(theta**(torch.arange(0,dim,2)[:(dim//2)].float()/dim))
    t=torch.arange(seq_len,device=freqs.device)
    freqs=torch.outer(t,freqs).float()
    freqs_cis=torch.polar(torch.ones_like(freqs),freqs)
    return freqs_cis

def apply_rotary_emb(q,k,freqs_cis,same=True):
    _q=q.float().reshape(*q.shape[:-1],-1,2)
    _k=k.float().reshape(*k.shape[:-1],-1,2)
    _q=torch.view_as_complex(_q)
    _k=torch.view_as_complex(_k)
    
    if same==False:
        if _k.shape[-2]%2!=0:
            q_out=torch.view_as_real(_q*freqs_cis[int((_k.shape[-2]-1)/2)].to(q.device)).flatten(-2)
        else:
            q_out=torch.view_as_real(_q*freqs_cis[_k.shape[-2]/2].to(q.device)).flatten(-2)
    else:
        q_out=torch.view_as_real(_q*freqs_cis[:_q.shape[-2]].to(q.device)).flatten(-2)
    k_out=torch.view_as_real(_k*freqs_cis[:_k.shape[-2]].to(k.device)).flatten(-2)
    return q_out.type_as(q),k_out.type_as(k)

# %%
class Attention(nn.Module):
    def __init__(self,c_q,c_k,c_v,c_hidden,no_heads,gating=True,use_rel_pos=False):
        super(Attention, self).__init__()
        self.c_q=c_q
        self.c_k=c_k
        self.c_v=c_v
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.gating=gating
        self.use_rel_pos=use_rel_pos

        self.linear_q=Linear(c_q,c_hidden*no_heads,bias=False,init="glorot")
        self.linear_k=Linear(c_k,c_hidden*no_heads,bias=False,init="glorot")
        self.linear_v=Linear(c_v,c_hidden*no_heads,bias=False,init="glorot")
        self.linear_o=Linear(c_hidden*no_heads,c_q,init="zero")
        if self.gating:
            self.linear_g=Linear(c_q,c_hidden*no_heads,init="gating")
        self.sigmoid=nn.Sigmoid()

        self.freqs_cis=None
        if self.use_rel_pos:
            self.freqs_cis=precompute_freqs_cis(c_hidden,MAX_SEQ_LEN)

    def forward(self,q_x,kv_x,biases=None):
        if(biases is None):
            biases=[]
        q=self.linear_q(q_x)
        k=self.linear_k(kv_x)
        v=self.linear_v(kv_x)
        q=q.view(q.shape[:-1]+(self.no_heads,-1))
        k=k.view(k.shape[:-1]+(self.no_heads,-1))
        v=v.view(v.shape[:-1]+(self.no_heads,-1))

        q=q.transpose(-2,-3)#r,H,s,h
        k=k.transpose(-2,-3)
        v=v.transpose(-2,-3)
        
        if self.use_rel_pos:
            q,k=apply_rotary_emb(q,k,freqs_cis=self.freqs_cis,same=True)
        k=permute_final_dims(k,(1,0))
        a=torch.matmul(q,k)/math.sqrt(self.c_hidden)#r,H,s,h * r,H,h,s = r,H,s,s
        for b in biases:
            a+=b
        a=torch.nn.functional.softmax(a,dim=-1)
        o=torch.matmul(a,v)#r,H,s,s * r,H,s,h = r,H,s,h
        o=o.transpose(-2,-3)#r,s,H,h

        if self.gating:
            g=self.sigmoid(self.linear_g(q_x))
            g=g.view(g.shape[:-1]+(self.no_heads,-1))
            o=o*g
        o=flatten_final_dims(o,2)#r,s,H*h
        o=self.linear_o(o)#r,s,o
        return o

# %%
class NanoAttention(nn.Module):
    def __init__(self,c_in,c_hidden,no_heads,inf=1e9,use_rel_pos=False):
        super(NanoAttention,self).__init__()
        self.c_in=c_in
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.inf=inf
        self.use_rel_pos=use_rel_pos
        self.layer_norm_x=LayerNorm(c_in)
        self.mha=Attention(c_in,c_in,c_in,c_hidden,no_heads,True,use_rel_pos)

    def forward(self,x,mask=None):
        n_seq,n_pos=x.shape[-3:-1]
        if mask is None:
            mask=x.new_ones(x.shape[:-3]+(n_seq,n_pos))
        mask_bias=(self.inf*(mask-1))[...,:,None,None,:]
        biases=[mask_bias]

        x=self.layer_norm_x(x)
        x=self.mha(x,x,biases)
        return x

class Trans_NanoAttention(nn.Module):
    def __init__(self,c_in,c_hidden,no_heads,inf=1e9,use_rel_pos=False):
        super(Trans_NanoAttention,self).__init__()
        self.c_in=c_in
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.inf=inf
        self.use_rel_pos=use_rel_pos
        self._NanoAttention=NanoAttention(c_in,c_hidden,no_heads,inf,use_rel_pos)

    def forward(self,x,mask=None):
        x=x.transpose(-2,-3)
        if mask is not None:
            mask=mask.transpose(-1,-2)
        x=self._NanoAttention(x,mask=mask)

        x=x.transpose(-2,-3)
        if mask is not None:
            mask=mask.transpose(-1,-2)
        return x

# %%
class GlobalAttention(nn.Module):
    def __init__(self,c_in,c_hidden,no_heads,inf=1e5,eps=1e-8,use_rel_pos=False):
        super(GlobalAttention,self).__init__()
        self.c_in=c_in
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.inf=inf
        self.eps=eps
        self.use_rel_pos=use_rel_pos
        
        self.linear_q=Linear(c_in,c_hidden*no_heads,bias=False,init="glorot")
        self.linear_k=Linear(c_in,c_hidden,bias=False,init="glorot")
        self.linear_v=Linear(c_in,c_hidden,bias=False,init="glorot")
        self.linear_g=Linear(c_in,c_hidden*no_heads,init="gating")
        self.linear_o=Linear(c_hidden*no_heads,c_in,init="zero")
        self.sigmoid=nn.Sigmoid()
        self.freqs_cis=None
        if self.use_rel_pos:
            self.freqs_cis=precompute_freqs_cis(c_hidden,MAX_SEQ_LEN)
    def forward(self,m,mask):
        q=torch.sum(m*mask.unsqueeze(-1),dim=-2)/(torch.sum(mask,dim=-1)[...,None]+self.eps)
        q=self.linear_q(q)
        k=self.linear_k(m)#r,s,h
        v=self.linear_v(m)#r,s,h
        q=q.view(q.shape[:-1]+(self.no_heads,-1))#r,H,h
        if self.use_rel_pos:
            q,k=apply_rotary_emb(q,k,freqs_cis=self.freqs_cis)
        
        bias=(self.inf*(mask-1))[...,:,None,:]
        a=torch.matmul(q,k.transpose(-1,-2))/math.sqrt(self.c_hidden)#r,H,h * r,h,s = r,H,s
        a+=bias
        a=torch.nn.functional.softmax(a,dim=-1)
        
        o=torch.matmul(a,v)#r,H,s * r,s,h = r,H,h
        g=self.sigmoid(self.linear_g(m))
        g=g.view(g.shape[:-1]+(self.no_heads,-1))
        o=o.unsqueeze(-3)*g#r,1,H,h * r,s,H,h = r,s,H,h
        o=o.reshape(o.shape[:-2]+(-1,))
        
        m=self.linear_o(o)#r,s,H*h->r,s,c_in
        return m

# %%
class GlobalNanoAttention(nn.Module):
    def __init__(self,c_in,c_hidden,no_heads,inf=1e9,eps=1e-8,use_rel_pos=False):
        super(GlobalNanoAttention,self).__init__()
        self.c_in=c_in
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.inf=inf
        self.use_rel_pos=use_rel_pos
        self.layer_norm_x=LayerNorm(c_in)
        self.gmha=GlobalAttention(c_in,c_hidden,no_heads,inf,eps,use_rel_pos)

    def forward(self,x,mask=None):
        n_seq,n_pos=x.shape[-3:-1]
        if mask is None:
            mask=x.new_ones(x.shape[:-3]+(n_seq,n_pos))
        x=self.layer_norm_x(x)
        x=self.gmha(x,mask)
        return x

class Trans_GlobalNanoAttention(nn.Module):
    def __init__(self,c_in,c_hidden,no_heads,inf=1e9,eps=1e-8,use_rel_pos=False):
        super(Trans_GlobalNanoAttention,self).__init__()
        self.c_in=c_in
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.inf=inf
        self.use_rel_pos=use_rel_pos
        self._GlobalNanoAttention=GlobalNanoAttention(c_in,c_hidden,no_heads,inf,eps,use_rel_pos)

    def forward(self,x,mask=None):
        x=x.transpose(-2,-3)
        if mask is not None:
            mask=mask.transpose(-1,-2)
        x=self._GlobalNanoAttention(x,mask=mask)
        x=x.transpose(-2,-3)
        if mask is not None:
            mask=mask.transpose(-1,-2)
        return x

# %%
class LineAttention(nn.Module):
    def __init__(self,c_in,c_hidden,no_heads,inf=1e5,eps=1e-8,use_rel_pos=False):
        super(LineAttention,self).__init__()
        self.c_in=c_in
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.inf=inf
        self.eps=eps
        self.use_rel_pos=use_rel_pos
        
        self.linear_q0=Linear(c_in,c_hidden*no_heads,bias=False,init="glorot")
        self.linear_k0=Linear(c_in,c_hidden,bias=False,init="glorot")
        self.linear_v0=Linear(c_in,c_hidden,bias=False,init="glorot")
        self.linear_q1=Linear(c_hidden,c_hidden,bias=False,init="glorot")
        self.linear_k1=Linear(c_hidden,c_hidden,bias=False,init="glorot")
        self.linear_v1=Linear(c_hidden,c_hidden,bias=False,init="glorot")
        self.linear_g=Linear(c_in,c_hidden*no_heads,init="gating")
        self.linear_q2=Linear(c_in,c_hidden*no_heads,bias=False,init="glorot")
        self.linear_k2=Linear(c_in,c_hidden*no_heads,bias=False,init="glorot")
        self.linear_v2=Linear(c_in,c_hidden*no_heads,bias=False,init="glorot")
        self.linear_o=Linear(c_hidden*no_heads,c_in,init="zero")
        self.sigmoid=nn.Sigmoid()
        self.freqs_cis=precompute_freqs_cis(c_hidden,MAX_SEQ_LEN)
    def forward(self,m,mask):
        l_sum=torch.sum(m*mask.unsqueeze(-1),dim=-2)/(torch.sum(mask,dim=-1)[...,None]+self.eps)
        q0=self.linear_q0(l_sum)
        k0=self.linear_k0(m)#r,s,h
        v0=self.linear_v0(m)#r,s,h
        q0=q0.view(q0.shape[:-1]+(self.no_heads,-1))#r,H,h
        if self.use_rel_pos:
            q0,k0=apply_rotary_emb(q0,k0,freqs_cis=self.freqs_cis,same=False)#r,H,h;r,s,h
        bias=(self.inf*(mask-1))[...,:,None,:]
        a0=torch.matmul(q0,k0.transpose(-1,-2))/math.sqrt(self.c_hidden)#r,H,h * r,h,s = r,H,s
        a0+=bias
        a0=torch.nn.functional.softmax(a0,dim=-1)
        r0=torch.matmul(a0,v0)#r,H,s * r,s,h = r,H,h
        
        q1=self.linear_q1(r0)
        k1=self.linear_q1(r0)
        v1=self.linear_q1(r0)
        q1=q1.transpose(-2,-3)
        k1=k1.transpose(-2,-3)
        v1=v1.transpose(-2,-3)
        if not self.use_rel_pos:
            q1,k1=apply_rotary_emb(q1,k1,freqs_cis=self.freqs_cis,same=True)#H,r,h;H,r,h
        a1=torch.matmul(q1,k1.transpose(-1,-2))/math.sqrt(self.c_hidden)#H,r,h * H,h,r = H,r,r
        a1=torch.nn.functional.softmax(a1,dim=-1)
        r1=torch.matmul(a1,v1)#H,r,r * H,r,h = H,r,h
        
        q2=self.linear_q2(m)
        k2=self.linear_k2(m)
        v2=self.linear_v2(m)
        q2=q2.view(q2.shape[:-1]+(self.no_heads,-1))
        k2=k2.view(k2.shape[:-1]+(self.no_heads,-1))
        v2=v2.view(v2.shape[:-1]+(self.no_heads,-1))
        q2=q2.transpose(-2,-3)#r,H,s,h
        k2=k2.transpose(-2,-3)
        v2=v2.transpose(-2,-3)
        if self.use_rel_pos:
            q2,k2=apply_rotary_emb(q2,k2,freqs_cis=self.freqs_cis,same=True)
        
        bias2=(self.inf*(mask-1))[...,:,None,None,:]
        a2=torch.matmul(q2,k2.transpose(-1,-2))/math.sqrt(self.c_hidden)#r,H,s,h * r,H,h,s = r,H,s,s
        a2+=bias2
        a2=torch.nn.functional.softmax(a2,dim=-1)
        r2=torch.matmul(a2,v2)#r,H,s,s * r,H,s,h = r,H,s,h
        r2=r2.transpose(-3,-4)#H,r,s,h
        
        g=self.sigmoid(self.linear_g(m))
        g=g.view(g.shape[:-1]+(self.no_heads,-1))
        g=g.transpose(-2,-3)
        g=g.transpose(-3,-4)
        
        if self.use_rel_pos:
            r1,_=apply_rotary_emb(r1,r2,freqs_cis=self.freqs_cis,same=False)#r,H,h;r,s,h
        r=(r1.unsqueeze(-2)+r2)*g#(H,r,1,h+H,r,s,h)*H,r,s,h=H,r,s,h
        r=r.transpose(-3,-4)
        r=r.transpose(-2,-3)
        r=r.reshape(r.shape[:-2]+(-1,))
        m=self.linear_o(r)#r,s,H*h->r,s,c_in
        return m

# %%
class LineNanoAttention(nn.Module):
    def __init__(self,c_in,c_hidden,no_heads,inf=1e9,eps=1e-8,use_rel_pos=False):
        super(LineNanoAttention,self).__init__()
        self.c_in=c_in
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.inf=inf
        self.use_rel_pos=use_rel_pos
        self.layer_norm_x=LayerNorm(c_in)
        self.lmha=LineAttention(c_in,c_hidden,no_heads,inf,eps,use_rel_pos)

    def forward(self,x,mask=None):
        n_seq,n_pos=x.shape[-3:-1]
        if mask is None:
            mask=x.new_ones(x.shape[:-3]+(n_seq,n_pos))
        x=self.layer_norm_x(x)
        x=self.lmha(x,mask)
        return x

class Trans_LineNanoAttention(nn.Module):
    def __init__(self,c_in,c_hidden,no_heads,inf=1e9,eps=1e-8,use_rel_pos=False):
        super(Trans_LineNanoAttention,self).__init__()
        self.c_in=c_in
        self.c_hidden=c_hidden
        self.no_heads=no_heads
        self.inf=inf
        self.use_rel_pos=use_rel_pos
        self._LineNanoAttention=LineNanoAttention(c_in,c_hidden,no_heads,inf,eps,use_rel_pos)

    def forward(self,x,mask=None):
        x=x.transpose(-2,-3)
        if mask is not None:
            mask=mask.transpose(-1,-2)
        x=self._LineNanoAttention(x,mask=mask)
        x=x.transpose(-2,-3)
        if mask is not None:
            mask=mask.transpose(-1,-2)
        return x

# %% [markdown]
# # Build Model

# %%
class NanoBlock(nn.Module):
    def __init__(self,c_x,c_hidden_att,no_heads,row_dropout,col_dropout,transition_n,inf,eps):
        super(NanoBlock,self).__init__()
        self.att_row=NanoAttention(c_x,c_hidden_att,no_heads,inf,use_rel_pos=True)
        self.att_col=Trans_NanoAttention(c_x,c_hidden_att,no_heads,inf,use_rel_pos=False)
        self.row_dropout_layer=DropoutRowwise(row_dropout)
        self.col_dropout_layer=DropoutColwise(col_dropout)

        self.layer_norm=LayerNorm(c_x)
        self.linear_1=Linear(c_x,transition_n*c_x,init="relu")
        self.relu=nn.ReLU()
        self.linear_2=Linear(transition_n*c_x,c_x,init="zero")
    def _transition(self,x):
        x=self.layer_norm(x)
        x=self.linear_1(x)
        x=self.relu(x)
        x=self.linear_2(x)
        return x

    def forward(self,x,x_mask):
        x=x+self.row_dropout_layer(self.att_row(x,x_mask))
        x=x+self.col_dropout_layer(self.att_col(x,x_mask))
        x=x+self._transition(x)
        return x

# %%
class NanoGlobalBlock(nn.Module):
    def __init__(self,c_x,c_hidden_att,no_heads,row_dropout,col_dropout,transition_n,inf,eps):
        super(NanoGlobalBlock,self).__init__()
        self.gatt_row=GlobalNanoAttention(c_x,c_hidden_att,no_heads,inf,eps,use_rel_pos=True)
        self.gatt_col=Trans_GlobalNanoAttention(c_x,c_hidden_att,no_heads,inf,eps,use_rel_pos=False)
        self.row_dropout_layer=DropoutRowwise(row_dropout)
        self.col_dropout_layer=DropoutColwise(col_dropout)

        self.layer_norm=LayerNorm(c_x)
        self.linear_1=Linear(c_x,transition_n*c_x,init="relu")
        self.relu=nn.ReLU()
        self.linear_2=Linear(transition_n*c_x,c_x,init="zero")
    def _transition(self,x):
        x=self.layer_norm(x)
        x=self.linear_1(x)
        x=self.relu(x)
        x=self.linear_2(x)
        return x

    def forward(self,x,x_mask):
        x=x+self.row_dropout_layer(self.gatt_row(x,x_mask))
        x=x+self.col_dropout_layer(self.gatt_col(x,x_mask))
        x=x+self._transition(x)
        return x

# %%
class NanoLineBlock(nn.Module):
    def __init__(self,c_x,c_hidden_att,no_heads,row_dropout,col_dropout,transition_n,inf,eps):
        super(NanoLineBlock,self).__init__()
        self.latt_row=LineNanoAttention(c_x,c_hidden_att,no_heads,inf,eps,use_rel_pos=True)
        self.latt_col=Trans_LineNanoAttention(c_x,c_hidden_att,no_heads,inf,eps,use_rel_pos=False)
        self.row_dropout_layer=DropoutRowwise(row_dropout)
        self.col_dropout_layer=DropoutColwise(col_dropout)

        self.layer_norm=LayerNorm(c_x)
        self.linear_1=Linear(c_x,transition_n*c_x,init="relu")
        self.relu=nn.ReLU()
        self.linear_2=Linear(transition_n*c_x,c_x,init="zero")
    def _transition(self,x):
        x=self.layer_norm(x)
        x=self.linear_1(x)
        x=self.relu(x)
        x=self.linear_2(x)
        return x

    def forward(self,x,x_mask):
        x=x+self.row_dropout_layer(self.latt_row(x,x_mask))
        x=x+self.col_dropout_layer(self.latt_col(x,x_mask))
        x=x+self._transition(x)
        return x

# %%
class NanoStack(nn.Module):
    def __init__(self,c_x,c_hidden_att,no_heads,blocks_lis,
        row_dropout,col_dropout,transition_n,
        inf,eps,clear_cache_between_blocks=False):
        super(NanoStack,self).__init__()
        self.clear_cache_between_blocks=clear_cache_between_blocks
        self.blocks=nn.ModuleList()
        for block_type in blocks_lis:
            if block_type==0:
                block=NanoBlock(c_x,c_hidden_att,no_heads,row_dropout,col_dropout,transition_n,inf,eps)
            elif block_type==1:
                block=NanoGlobalBlock(c_x,c_hidden_att,no_heads,row_dropout,col_dropout,transition_n,inf,eps)
            elif block_type==2:
                block=NanoLineBlock(c_x,c_hidden_att,no_heads,row_dropout,col_dropout,transition_n,inf,eps)
            self.blocks.append(block)

    def _prep_blocks(self,x_mask):
        blocks=[partial(b,x_mask=x_mask)for b in self.blocks]
        if(self.clear_cache_between_blocks):
            def block_with_cache_clear(block,*args,**kwargs):
                torch.cuda.empty_cache()
                return block(*args,**kwargs)
            blocks=[partial(block_with_cache_clear,b) for b in blocks]
        return blocks

    def forward(self,x,x_mask):
        blocks=self._prep_blocks(x_mask)
        for block in blocks:
            x=block(x)
        return x

# %%
class Nano(nn.Module):
    def __init__(self,c_s,c_x,c_emb,c_f,c_hidden_att,c_o,no_heads,blocks_lis,
                row_dropout,col_dropout,transition_n,inf=1e9,eps=1e-8,clear_cache_between_blocks=False):
        super(Nano,self).__init__()
        self.s_embedder=LinearEmbedder(c_s,c_emb)
        self.x_embedder=LinearEmbedder(c_x,c_emb)
        self.stack=NanoStack(c_emb,c_hidden_att,no_heads,blocks_lis,
                     row_dropout,col_dropout,transition_n,inf,eps,clear_cache_between_blocks)
        self.linear_f=Linear(c_emb,c_f)
        self.classifier=nn.Sequential(
            nn.Linear(c_f,int(c_f/2)),
            nn.ReLU(),
            nn.Linear(int(c_f/2),c_o),
            nn.Sigmoid()
        )
    def forward(self,s,x,s_mask,x_mask):
        s=self.s_embedder(s)
        x=self.x_embedder(x)
        
        x=torch.cat([s.unsqueeze(-3),x],dim=-3)
        x_mask=torch.cat([s_mask.unsqueeze(-2),x_mask],dim=-2)

        x=self.stack(x,x_mask)
        x=self.linear_f(torch.mean(x[...,:,int(x.shape[-2]/2)+1,:],-2))
        #x=self.linear_f(torch.max(x[...,:,int(x.shape[-2]/2)+1,:],-2)[0])
        o=self.classifier(x).squeeze(-1)
        return o

# %% [markdown]
# # For Train and Test

# %%
def test(model,test_loader,device,line_reduce=0,col_reduce=0):
    model.eval()
    right_count,all_count=0,0
    prob_all,by_all=[],[]
    with torch.no_grad():
        for _,l_dic in enumerate(test_loader):
            by=l_dic['label'].to(device)
            by=by.to(torch.int64)
            if line_reduce==0:
                seq_feature=l_dic['seq_feature'].to(device)
                seq_mask=l_dic['seq_mask'].to(device)
                nano_feature=l_dic['nano_feature'][:,col_reduce:].to(device)
                nano_mask=l_dic['nano_mask'][:,col_reduce:].to(device)
            else:
                side_reduce=int(line_reduce/2)
                seq_feature=l_dic['seq_feature'][:,side_reduce:-side_reduce].to(device)
                seq_mask=l_dic['seq_mask'][:,side_reduce:-side_reduce].to(device)
                nano_feature=l_dic['nano_feature'][:,col_reduce:,side_reduce:-side_reduce].to(device)
                nano_mask=l_dic['nano_mask'][:,col_reduce:,side_reduce:-side_reduce].to(device)
            ry=model(seq_feature,nano_feature,seq_mask,nano_mask)
            out_y=ry>0.5
            right_count+=out_y.eq(by).sum()
            all_count+=len(by)
            for each in ry:
                prob_all.append(np.array(each.cpu()))
            for each in by:
                by_all.append(np.array(each.cpu()))
    roauc=roc_auc_score(by_all,prob_all)

    accuracy=100*(right_count/all_count).item()
    print('AUC:{:.4f}   accuracy:{:.4f}%'.format(roauc,accuracy))
    torch.cuda.empty_cache()

def train(model,train_loader,test_loader,device,optimizer,loss_func,epochs,line_reduce=0,col_reduce=0):
    torch.cuda.empty_cache()
    for epoch in range(epochs):
        total_loss=0
        model.train()
        for _,l_dic in enumerate(train_loader):
            by=l_dic['label'].to(device)
            if line_reduce==0:
                seq_feature=l_dic['seq_feature'].to(device)
                seq_mask=l_dic['seq_mask'].to(device)
                nano_feature=l_dic['nano_feature'][:,col_reduce:].to(device)
                nano_mask=l_dic['nano_mask'][:,col_reduce:].to(device)
            else:
                side_reduce=int(line_reduce/2)
                seq_feature=l_dic['seq_feature'][:,side_reduce:-side_reduce].to(device)
                seq_mask=l_dic['seq_mask'][:,side_reduce:-side_reduce].to(device)
                nano_feature=l_dic['nano_feature'][:,col_reduce:,side_reduce:-side_reduce].to(device)
                nano_mask=l_dic['nano_mask'][:,col_reduce:,side_reduce:-side_reduce].to(device)
            ry=model(seq_feature,nano_feature,seq_mask,nano_mask)
            loss=loss_func(ry,by.float())
            total_loss+=loss
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        print('epoch '+str(epoch+1)+' loss:  ',total_loss/len(test_loader))        
        if epoch%10==9:
            print('At epoch '+str(epoch+1),':')
            test(model,test_loader,device,line_reduce,col_reduce)
            torch.save(model.state_dict(),'./model/model_'+str(epoch+1)+'_'+str(int(time.time()))+'.pkl')

# %%
def detailed_test(model,test_loader,device,line_reduce=0,col_reduce=0,curve_name=None,histo_name=None):
    model.eval()
    right_count,all_count=0,0
    more_dict={0.5:[0,0],0.6:[0,0],0.8:[0,0],0.7:[0,0],0.9:[0,0],0.95:[0,0],0.98:[0,0],\
               0.99:[0,0],0.995:[0,0],0.999:[0,0],0.9995:[0,0],0.9999:[0,0],0.99995:[0,0],\
               0.99999:[0,0],0.999995:[0,0],0.999999:[0,0]}
    prob_all,by_all=[],[]
    motif_dict={}
    range_list=[]
    with torch.no_grad():
        for _,l_dic in enumerate(test_loader):
            by=l_dic['label'].to(device).to(torch.int64)
            if line_reduce==0:
                seq_feature=l_dic['seq_feature'].to(device)
                seq_mask=l_dic['seq_mask'].to(device)
                nano_feature=l_dic['nano_feature'][:,col_reduce:].to(device)
                nano_mask=l_dic['nano_mask'][:,col_reduce:].to(device)
            else:
                side_reduce=int(line_reduce/2)
                seq_feature=l_dic['seq_feature'][:,side_reduce:-side_reduce].to(device)
                seq_mask=l_dic['seq_mask'][:,side_reduce:-side_reduce].to(device)
                nano_feature=l_dic['nano_feature'][:,col_reduce:,side_reduce:-side_reduce].to(device)
                nano_mask=l_dic['nano_mask'][:,col_reduce:,side_reduce:-side_reduce].to(device)
            ry=model(seq_feature,nano_feature,seq_mask,nano_mask)
            out_y=ry>0.5
            right_count+=out_y.eq(by).sum()
            all_count+=len(by)
            for each in ry:
                prob_all.append(np.array(each.cpu()))
            for each in by:
                by_all.append(np.array(each.cpu()))
            for key in more_dict:
                more_dict[key][0]+=((ry>key)&by).sum()
                more_dict[key][1]+=(ry>key).sum()

            if histo_name:
                middle_pos=int((len(l_dic['seq_feature'][0])-1)/2)
                center_seqs=l_dic['seq_feature'][:,middle_pos-2:middle_pos+3]            
                for i in range(len(by)):
                    _Seq=''
                    for j in range(5):
                        if abs(center_seqs[i][j][0]-1)<0.01:
                            _Seq+='A'
                        elif abs(center_seqs[i][j][1]-1)<0.01:
                            _Seq+='T'
                        elif abs(center_seqs[i][j][2]-1)<0.01:
                            _Seq+='C'
                        elif abs(center_seqs[i][j][3]-1)<0.01:
                            _Seq+='G'
                        else:
                            _Seq+='N'
                    if 'N' not in _Seq:
                        if _Seq not in motif_dict:
                            motif_dict[_Seq]={'TP':0,'FP':0,'TN':0,'FN':0}
                        if out_y[i]==1 and by[i]==1:
                            motif_dict[_Seq]['TP']+=1
                        elif out_y[i]==1 and by[i]==0:
                            motif_dict[_Seq]['FP']+=1
                        elif out_y[i]==0 and by[i]==0:
                            motif_dict[_Seq]['TN']+=1
                        elif out_y[i]==0 and by[i]==1:
                            motif_dict[_Seq]['FN']+=1
                for i in range(len(ry)):
                    range_list.append([ry[i].cpu().item(),by[i].cpu().item()])
    if histo_name:
        save_frame=pd.DataFrame(motif_dict).T
        save_frame.to_csv('./edata/Save_for_drawing/'+histo_name+'_motif_histo.csv',index=True,sep=',')
        save_frame=pd.DataFrame(range_list)
        save_frame.columns=['Probability score','Ground Truth']
        save_frame.to_csv('./edata/Save_for_drawing/'+histo_name+'_range_histo.csv',index=False,sep=',')
    if curve_name:
        save_frame=pd.DataFrame({'label':by_all,'pred':prob_all})
        save_frame.to_csv('./edata/Save_for_drawing/'+curve_name+'_curve.csv',index=False,sep=',')

    print('Im total',all_count,'samples:')
    auc=roc_auc_score(by_all,prob_all)
    accuracy=100*(right_count/all_count).item()
    print('AUC:{:.4f}   accuracy:{:.4f}%'.format(auc,accuracy))
    for key in more_dict:
        if more_dict[key][1]>0:
            print('Precision when positive threshold at {:g} is :{:.4f}% (total:{:d})'.format(key,more_dict[key][0]/more_dict[key][1],more_dict[key][1]))
    torch.cuda.empty_cache()

# %% [markdown]
# # Train

# %%
device=torch.device('cuda:0')
model=Nano(c_s=4,c_x=3,c_emb=96,c_f=16,c_hidden_att=64,c_o=1,no_heads=8,blocks_lis=[2,2,2,0,0,0],
            row_dropout=0.1,col_dropout=0.1,transition_n=2,inf=1e9,eps=1e-8,
            clear_cache_between_blocks=False).to(device)
optimizer=optim.Adam(model.parameters(),lr=0.0001)
loss_func=nn.BCELoss().to(device)
epochs=300
train(model,m5C_Nano_train_loader,m5C_Nano_test_loader,device,optimizer,loss_func,epochs,0,0)
# Out:
# epoch 1 loss:   tensor(2.5643, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 2 loss:   tensor(2.2738, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 3 loss:   tensor(2.1611, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 4 loss:   tensor(2.1215, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 5 loss:   tensor(2.0797, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 6 loss:   tensor(2.0458, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 7 loss:   tensor(1.9788, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 8 loss:   tensor(1.9488, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 9 loss:   tensor(1.9025, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 10 loss:   tensor(1.8760, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 10 :
# AUC:0.8478   accuracy:76.8559%
# epoch 11 loss:   tensor(1.8268, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 12 loss:   tensor(1.7704, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 13 loss:   tensor(1.7357, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 14 loss:   tensor(1.6763, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 15 loss:   tensor(1.6085, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 16 loss:   tensor(1.5592, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 17 loss:   tensor(1.4860, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 18 loss:   tensor(1.4407, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 19 loss:   tensor(1.4128, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 20 loss:   tensor(1.3531, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 20 :
# AUC:0.9026   accuracy:82.5328%
# epoch 21 loss:   tensor(1.2985, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 22 loss:   tensor(1.2520, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 23 loss:   tensor(1.2050, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 24 loss:   tensor(1.1980, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 25 loss:   tensor(1.1498, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 26 loss:   tensor(1.1197, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 27 loss:   tensor(1.0391, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 28 loss:   tensor(1.0924, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 29 loss:   tensor(1.0102, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 30 loss:   tensor(0.9712, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 30 :
# AUC:0.9095   accuracy:83.9301%
# epoch 31 loss:   tensor(0.9502, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 32 loss:   tensor(0.9440, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 33 loss:   tensor(0.9058, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 34 loss:   tensor(0.9111, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 35 loss:   tensor(0.8439, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 36 loss:   tensor(0.7895, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 37 loss:   tensor(0.8183, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 38 loss:   tensor(0.7357, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 39 loss:   tensor(0.7225, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 40 loss:   tensor(0.7607, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 40 :
# AUC:0.9196   accuracy:85.2402%
# epoch 41 loss:   tensor(0.6479, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 42 loss:   tensor(0.6496, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 43 loss:   tensor(0.6416, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 44 loss:   tensor(0.6107, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 45 loss:   tensor(0.6030, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 46 loss:   tensor(0.6044, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 47 loss:   tensor(0.5310, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 48 loss:   tensor(0.4699, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 49 loss:   tensor(0.5034, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 50 loss:   tensor(0.4919, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 50 :
# AUC:0.9164   accuracy:85.1528%
# epoch 51 loss:   tensor(0.4367, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 52 loss:   tensor(0.4570, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 53 loss:   tensor(0.4298, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 54 loss:   tensor(0.3831, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 55 loss:   tensor(0.3725, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 56 loss:   tensor(0.3823, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 57 loss:   tensor(0.3738, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 58 loss:   tensor(0.3841, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 59 loss:   tensor(0.3152, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 60 loss:   tensor(0.3364, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 60 :
# AUC:0.9270   accuracy:87.5983%
# epoch 61 loss:   tensor(0.3462, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 62 loss:   tensor(0.2837, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 63 loss:   tensor(0.3355, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 64 loss:   tensor(0.2482, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 65 loss:   tensor(0.3391, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 66 loss:   tensor(0.2483, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 67 loss:   tensor(0.3863, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 68 loss:   tensor(0.2647, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 69 loss:   tensor(0.2647, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 70 loss:   tensor(0.2198, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 70 :
# AUC:0.9336   accuracy:87.5983%
# epoch 71 loss:   tensor(0.2751, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 72 loss:   tensor(0.2255, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 73 loss:   tensor(0.2157, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 74 loss:   tensor(0.2944, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 75 loss:   tensor(0.2211, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 76 loss:   tensor(0.2493, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 77 loss:   tensor(0.2315, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 78 loss:   tensor(0.2178, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 79 loss:   tensor(0.2353, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 80 loss:   tensor(0.2006, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 80 :
# AUC:0.9289   accuracy:87.0742%
# epoch 81 loss:   tensor(0.2479, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 82 loss:   tensor(0.2097, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 83 loss:   tensor(0.1358, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 84 loss:   tensor(0.2145, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 85 loss:   tensor(0.2141, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 86 loss:   tensor(0.1987, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 87 loss:   tensor(0.1954, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 88 loss:   tensor(0.1915, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 89 loss:   tensor(0.1279, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 90 loss:   tensor(0.2038, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 90 :
# AUC:0.9321   accuracy:87.2489%
# epoch 91 loss:   tensor(0.1909, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 92 loss:   tensor(0.1725, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 93 loss:   tensor(0.1371, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 94 loss:   tensor(0.2699, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 95 loss:   tensor(0.1408, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 96 loss:   tensor(0.1834, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 97 loss:   tensor(0.1733, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 98 loss:   tensor(0.1543, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 99 loss:   tensor(0.1526, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 100 loss:   tensor(0.1333, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 100 :
# AUC:0.9329   accuracy:87.7729%
# epoch 101 loss:   tensor(0.1601, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 102 loss:   tensor(0.0936, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 103 loss:   tensor(0.1592, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 104 loss:   tensor(0.1299, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 105 loss:   tensor(0.1556, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 106 loss:   tensor(0.1353, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 107 loss:   tensor(0.1664, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 108 loss:   tensor(0.1240, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 109 loss:   tensor(0.1120, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 110 loss:   tensor(0.1375, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 110 :
# AUC:0.9338   accuracy:87.0742%
# epoch 111 loss:   tensor(0.1572, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 112 loss:   tensor(0.1177, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 113 loss:   tensor(0.1803, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 114 loss:   tensor(0.1151, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 115 loss:   tensor(0.1035, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 116 loss:   tensor(0.1366, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 117 loss:   tensor(0.1289, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 118 loss:   tensor(0.1490, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 119 loss:   tensor(0.0603, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 120 loss:   tensor(0.2141, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 120 :
# AUC:0.9384   accuracy:88.1223%
# epoch 121 loss:   tensor(0.0748, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 122 loss:   tensor(0.1024, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 123 loss:   tensor(0.1781, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 124 loss:   tensor(0.1081, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 125 loss:   tensor(0.1349, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 126 loss:   tensor(0.1046, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 127 loss:   tensor(0.1161, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 128 loss:   tensor(0.1133, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 129 loss:   tensor(0.1337, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 130 loss:   tensor(0.0737, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 130 :
# AUC:0.9301   accuracy:86.3755%
# epoch 131 loss:   tensor(0.1027, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 132 loss:   tensor(0.1147, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 133 loss:   tensor(0.0991, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 134 loss:   tensor(0.1451, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 135 loss:   tensor(0.0670, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 136 loss:   tensor(0.1532, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 137 loss:   tensor(0.0679, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 138 loss:   tensor(0.1114, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 139 loss:   tensor(0.0592, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 140 loss:   tensor(0.1899, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 140 :
# AUC:0.9362   accuracy:86.6376%
# epoch 141 loss:   tensor(0.0898, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 142 loss:   tensor(0.0656, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 143 loss:   tensor(0.0606, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 144 loss:   tensor(0.1311, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 145 loss:   tensor(0.1451, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 146 loss:   tensor(0.0566, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 147 loss:   tensor(0.1320, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 148 loss:   tensor(0.0344, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 149 loss:   tensor(0.1659, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 150 loss:   tensor(0.0665, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 150 :
# AUC:0.9444   accuracy:88.3843%
# epoch 151 loss:   tensor(0.0706, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 152 loss:   tensor(0.1047, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 153 loss:   tensor(0.1092, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 154 loss:   tensor(0.0574, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 155 loss:   tensor(0.1566, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 156 loss:   tensor(0.0748, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 157 loss:   tensor(0.0513, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 158 loss:   tensor(0.0957, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 159 loss:   tensor(0.1285, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 160 loss:   tensor(0.0810, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 160 :
# AUC:0.9301   accuracy:85.5895%
# epoch 161 loss:   tensor(0.0619, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 162 loss:   tensor(0.1358, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 163 loss:   tensor(0.0836, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 164 loss:   tensor(0.1038, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 165 loss:   tensor(0.0914, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 166 loss:   tensor(0.0718, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 167 loss:   tensor(0.0727, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 168 loss:   tensor(0.1078, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 169 loss:   tensor(0.0878, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 170 loss:   tensor(0.0636, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 170 :
# AUC:0.9421   accuracy:88.1223%
# epoch 171 loss:   tensor(0.1175, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 172 loss:   tensor(0.0604, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 173 loss:   tensor(0.1292, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 174 loss:   tensor(0.0486, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 175 loss:   tensor(0.0914, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 176 loss:   tensor(0.0483, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 177 loss:   tensor(0.1052, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 178 loss:   tensor(0.0636, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 179 loss:   tensor(0.0914, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 180 loss:   tensor(0.0784, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 180 :
# AUC:0.9344   accuracy:87.7729%
# epoch 181 loss:   tensor(0.0508, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 182 loss:   tensor(0.0770, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 183 loss:   tensor(0.0550, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 184 loss:   tensor(0.1132, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 185 loss:   tensor(0.0630, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 186 loss:   tensor(0.0346, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 187 loss:   tensor(0.1158, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 188 loss:   tensor(0.0656, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 189 loss:   tensor(0.0965, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 190 loss:   tensor(0.0494, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 190 :
# AUC:0.9368   accuracy:87.5109%
# epoch 191 loss:   tensor(0.0413, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 192 loss:   tensor(0.1492, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 193 loss:   tensor(0.0265, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 194 loss:   tensor(0.0293, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 195 loss:   tensor(0.1256, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 196 loss:   tensor(0.1314, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 197 loss:   tensor(0.0265, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 198 loss:   tensor(0.0266, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 199 loss:   tensor(0.1364, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 200 loss:   tensor(0.0760, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 200 :
# AUC:0.9435   accuracy:88.0349%
# epoch 201 loss:   tensor(0.0723, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 202 loss:   tensor(0.0376, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 203 loss:   tensor(0.1118, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 204 loss:   tensor(0.0943, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 205 loss:   tensor(0.0446, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 206 loss:   tensor(0.0555, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 207 loss:   tensor(0.0428, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 208 loss:   tensor(0.1271, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 209 loss:   tensor(0.0383, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 210 loss:   tensor(0.0543, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 210 :
# AUC:0.9332   accuracy:86.3755%
# epoch 211 loss:   tensor(0.0637, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 212 loss:   tensor(0.0614, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 213 loss:   tensor(0.0615, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 214 loss:   tensor(0.0707, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 215 loss:   tensor(0.1037, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 216 loss:   tensor(0.0435, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 217 loss:   tensor(0.0311, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 218 loss:   tensor(0.0568, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 219 loss:   tensor(0.0707, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 220 loss:   tensor(0.0891, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 220 :
# AUC:0.9396   accuracy:88.6463%
# epoch 221 loss:   tensor(0.0390, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 222 loss:   tensor(0.0872, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 223 loss:   tensor(0.0274, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 224 loss:   tensor(0.0342, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 225 loss:   tensor(0.0923, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 226 loss:   tensor(0.0666, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 227 loss:   tensor(0.0169, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 228 loss:   tensor(0.1153, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 229 loss:   tensor(0.0959, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 230 loss:   tensor(0.0273, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 230 :
# AUC:0.9462   accuracy:88.2096%
# epoch 231 loss:   tensor(0.0118, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 232 loss:   tensor(0.1541, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 233 loss:   tensor(0.0370, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 234 loss:   tensor(0.0407, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 235 loss:   tensor(0.0805, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 236 loss:   tensor(0.0669, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 237 loss:   tensor(0.0752, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 238 loss:   tensor(0.0666, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 239 loss:   tensor(0.0699, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 240 loss:   tensor(0.0214, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 240 :
# AUC:0.9466   accuracy:88.1223%
# epoch 241 loss:   tensor(0.0363, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 242 loss:   tensor(0.0627, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 243 loss:   tensor(0.1007, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 244 loss:   tensor(0.0512, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 245 loss:   tensor(0.0651, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 246 loss:   tensor(0.0271, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 247 loss:   tensor(0.0817, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 248 loss:   tensor(0.0603, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 249 loss:   tensor(0.0680, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 250 loss:   tensor(0.0450, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 250 :
# AUC:0.9506   accuracy:89.2576%
# epoch 251 loss:   tensor(0.0768, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 252 loss:   tensor(0.0188, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 253 loss:   tensor(0.1026, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 254 loss:   tensor(0.0376, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 255 loss:   tensor(0.0629, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 256 loss:   tensor(0.0703, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 257 loss:   tensor(0.0733, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 258 loss:   tensor(0.0416, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 259 loss:   tensor(0.0732, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 260 loss:   tensor(0.0249, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 260 :
# AUC:0.9516   accuracy:88.6463%
# epoch 261 loss:   tensor(0.0318, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 262 loss:   tensor(0.0659, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 263 loss:   tensor(0.0614, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 264 loss:   tensor(0.0673, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 265 loss:   tensor(0.0825, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 266 loss:   tensor(0.0473, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 267 loss:   tensor(0.0227, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 268 loss:   tensor(0.0633, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 269 loss:   tensor(0.0732, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 270 loss:   tensor(0.0097, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 270 :
# AUC:0.9501   accuracy:89.2576%
# epoch 271 loss:   tensor(0.0386, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 272 loss:   tensor(0.0731, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 273 loss:   tensor(0.0428, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 274 loss:   tensor(0.1007, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 275 loss:   tensor(0.0355, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 276 loss:   tensor(0.0332, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 277 loss:   tensor(0.0484, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 278 loss:   tensor(0.0256, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 279 loss:   tensor(0.1168, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 280 loss:   tensor(0.0337, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 280 :
# AUC:0.9481   accuracy:88.2969%
# epoch 281 loss:   tensor(0.0131, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 282 loss:   tensor(0.0248, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 283 loss:   tensor(0.1184, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 284 loss:   tensor(0.0182, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 285 loss:   tensor(0.0393, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 286 loss:   tensor(0.0701, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 287 loss:   tensor(0.0728, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 288 loss:   tensor(0.0349, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 289 loss:   tensor(0.0179, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 290 loss:   tensor(0.0273, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 290 :
# AUC:0.9510   accuracy:89.0830%
# epoch 291 loss:   tensor(0.0789, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 292 loss:   tensor(0.0375, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 293 loss:   tensor(0.0497, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 294 loss:   tensor(0.0732, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 295 loss:   tensor(0.0234, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 296 loss:   tensor(0.0314, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 297 loss:   tensor(0.1075, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 298 loss:   tensor(0.0419, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 299 loss:   tensor(0.0134, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 300 loss:   tensor(0.0543, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 300 :
# AUC:0.9499   accuracy:88.2969%

# %%
device=torch.device('cuda:0')
model=Nano(c_s=4,c_x=3,c_emb=96,c_f=16,c_hidden_att=64,c_o=1,no_heads=8,blocks_lis=[2,2,0,0,1,1],
            row_dropout=0.1,col_dropout=0.1,transition_n=2,inf=1e9,eps=1e-8,
            clear_cache_between_blocks=False).to(device)
optimizer=optim.Adam(model.parameters(),lr=0.0001)
loss_func=nn.BCELoss().to(device)
epochs=300
train(model,m5C_Nano_train_loader,m5C_Nano_test_loader,device,optimizer,loss_func,epochs,0,0)
# Out:
# epoch 1 loss:   tensor(2.5054, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 2 loss:   tensor(2.2480, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 3 loss:   tensor(2.1425, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 4 loss:   tensor(2.0561, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 5 loss:   tensor(2.0239, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 6 loss:   tensor(1.9581, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 7 loss:   tensor(1.9252, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 8 loss:   tensor(1.8546, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 9 loss:   tensor(1.8025, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 10 loss:   tensor(1.7595, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 10 :
# AUC:0.8706   accuracy:78.0786%
# epoch 11 loss:   tensor(1.7013, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 12 loss:   tensor(1.6787, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 13 loss:   tensor(1.6382, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 14 loss:   tensor(1.5794, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 15 loss:   tensor(1.5523, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 16 loss:   tensor(1.5047, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 17 loss:   tensor(1.4523, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 18 loss:   tensor(1.4277, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 19 loss:   tensor(1.4055, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 20 loss:   tensor(1.3429, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 20 :
# AUC:0.8949   accuracy:80.6114%
# epoch 21 loss:   tensor(1.3115, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 22 loss:   tensor(1.2705, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 23 loss:   tensor(1.2373, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 24 loss:   tensor(1.2197, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 25 loss:   tensor(1.2156, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 26 loss:   tensor(1.1703, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 27 loss:   tensor(1.1452, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 28 loss:   tensor(1.1253, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 29 loss:   tensor(1.0420, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 30 loss:   tensor(1.0327, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 30 :
# AUC:0.9123   accuracy:83.6681%
# epoch 31 loss:   tensor(1.0136, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 32 loss:   tensor(0.9355, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 33 loss:   tensor(0.9450, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 34 loss:   tensor(0.8916, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 35 loss:   tensor(0.9016, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 36 loss:   tensor(0.8539, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 37 loss:   tensor(0.8274, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 38 loss:   tensor(0.7855, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 39 loss:   tensor(0.7992, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 40 loss:   tensor(0.7256, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 40 :
# AUC:0.9226   accuracy:85.5895%
# epoch 41 loss:   tensor(0.7294, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 42 loss:   tensor(0.7351, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 43 loss:   tensor(0.6672, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 44 loss:   tensor(0.6103, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 45 loss:   tensor(0.6155, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 46 loss:   tensor(0.5945, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 47 loss:   tensor(0.5734, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 48 loss:   tensor(0.5501, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 49 loss:   tensor(0.5178, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 50 loss:   tensor(0.5305, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 50 :
# AUC:0.9287   accuracy:86.3755%
# epoch 51 loss:   tensor(0.4871, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 52 loss:   tensor(0.4972, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 53 loss:   tensor(0.4705, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 54 loss:   tensor(0.4189, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 55 loss:   tensor(0.4112, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 56 loss:   tensor(0.4183, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 57 loss:   tensor(0.3851, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 58 loss:   tensor(0.4492, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 59 loss:   tensor(0.3484, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 60 loss:   tensor(0.3225, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 60 :
# AUC:0.9319   accuracy:87.1616%
# epoch 61 loss:   tensor(0.3736, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 62 loss:   tensor(0.2979, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 63 loss:   tensor(0.3766, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 64 loss:   tensor(0.3994, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 65 loss:   tensor(0.3080, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 66 loss:   tensor(0.3383, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 67 loss:   tensor(0.2215, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 68 loss:   tensor(0.3753, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 69 loss:   tensor(0.2709, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 70 loss:   tensor(0.3199, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 70 :
# AUC:0.9226   accuracy:86.7249%
# epoch 71 loss:   tensor(0.2406, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 72 loss:   tensor(0.3294, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 73 loss:   tensor(0.2334, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 74 loss:   tensor(0.2203, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 75 loss:   tensor(0.2202, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 76 loss:   tensor(0.2903, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 77 loss:   tensor(0.2292, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 78 loss:   tensor(0.1469, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 79 loss:   tensor(0.2703, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 80 loss:   tensor(0.2424, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 80 :
# AUC:0.9287   accuracy:86.7249%
# epoch 81 loss:   tensor(0.1925, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 82 loss:   tensor(0.2248, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 83 loss:   tensor(0.1817, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 84 loss:   tensor(0.1781, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 85 loss:   tensor(0.2545, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 86 loss:   tensor(0.1692, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 87 loss:   tensor(0.1960, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 88 loss:   tensor(0.1734, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 89 loss:   tensor(0.2021, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 90 loss:   tensor(0.1799, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 90 :
# AUC:0.9333   accuracy:86.7249%
# epoch 91 loss:   tensor(0.2187, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 92 loss:   tensor(0.1766, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 93 loss:   tensor(0.1578, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 94 loss:   tensor(0.2067, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 95 loss:   tensor(0.1423, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 96 loss:   tensor(0.1761, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 97 loss:   tensor(0.1950, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 98 loss:   tensor(0.1853, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 99 loss:   tensor(0.1369, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 100 loss:   tensor(0.1677, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 100 :
# AUC:0.9323   accuracy:86.5502%
# epoch 101 loss:   tensor(0.1816, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 102 loss:   tensor(0.1607, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 103 loss:   tensor(0.1424, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 104 loss:   tensor(0.1381, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 105 loss:   tensor(0.1848, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 106 loss:   tensor(0.1474, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 107 loss:   tensor(0.1742, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 108 loss:   tensor(0.1027, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 109 loss:   tensor(0.1289, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 110 loss:   tensor(0.1544, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 110 :
# AUC:0.9430   accuracy:88.0349%
# epoch 111 loss:   tensor(0.1675, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 112 loss:   tensor(0.1242, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 113 loss:   tensor(0.1587, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 114 loss:   tensor(0.1038, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 115 loss:   tensor(0.0349, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 116 loss:   tensor(0.2675, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 117 loss:   tensor(0.1041, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 118 loss:   tensor(0.1567, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 119 loss:   tensor(0.1093, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 120 loss:   tensor(0.1102, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 120 :
# AUC:0.9407   accuracy:86.2882%
# epoch 121 loss:   tensor(0.1163, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 122 loss:   tensor(0.1079, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 123 loss:   tensor(0.1488, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 124 loss:   tensor(0.0771, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 125 loss:   tensor(0.1350, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 126 loss:   tensor(0.1109, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 127 loss:   tensor(0.0987, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 128 loss:   tensor(0.1276, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 129 loss:   tensor(0.1685, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 130 loss:   tensor(0.1074, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 130 :
# AUC:0.9451   accuracy:88.7336%
# epoch 131 loss:   tensor(0.1236, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 132 loss:   tensor(0.0726, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 133 loss:   tensor(0.1392, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 134 loss:   tensor(0.0895, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 135 loss:   tensor(0.0883, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 136 loss:   tensor(0.1807, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 137 loss:   tensor(0.0811, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 138 loss:   tensor(0.0846, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 139 loss:   tensor(0.1253, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 140 loss:   tensor(0.1132, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 140 :
# AUC:0.9373   accuracy:87.0742%
# epoch 141 loss:   tensor(0.0770, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 142 loss:   tensor(0.1332, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 143 loss:   tensor(0.0767, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 144 loss:   tensor(0.1283, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 145 loss:   tensor(0.0605, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 146 loss:   tensor(0.1225, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 147 loss:   tensor(0.0636, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 148 loss:   tensor(0.1053, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 149 loss:   tensor(0.0663, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 150 loss:   tensor(0.1327, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 150 :
# AUC:0.9457   accuracy:88.9083%
# epoch 151 loss:   tensor(0.0881, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 152 loss:   tensor(0.1159, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 153 loss:   tensor(0.1023, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 154 loss:   tensor(0.0692, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 155 loss:   tensor(0.1450, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 156 loss:   tensor(0.0333, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 157 loss:   tensor(0.1280, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 158 loss:   tensor(0.0647, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 159 loss:   tensor(0.1350, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 160 loss:   tensor(0.1114, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 160 :
# AUC:0.9481   accuracy:88.9956%
# epoch 161 loss:   tensor(0.0672, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 162 loss:   tensor(0.0978, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 163 loss:   tensor(0.1041, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 164 loss:   tensor(0.0968, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 165 loss:   tensor(0.0690, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 166 loss:   tensor(0.1122, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 167 loss:   tensor(0.1140, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 168 loss:   tensor(0.0587, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 169 loss:   tensor(0.0070, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 170 loss:   tensor(0.1629, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 170 :
# AUC:0.9444   accuracy:88.2096%
# epoch 171 loss:   tensor(0.0825, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 172 loss:   tensor(0.1130, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 173 loss:   tensor(0.0810, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 174 loss:   tensor(0.1097, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 175 loss:   tensor(0.0673, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 176 loss:   tensor(0.0438, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 177 loss:   tensor(0.1186, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 178 loss:   tensor(0.0822, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 179 loss:   tensor(0.0583, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 180 loss:   tensor(0.0762, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 180 :
# AUC:0.9535   accuracy:89.6943%
# epoch 181 loss:   tensor(0.0815, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 182 loss:   tensor(0.1124, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 183 loss:   tensor(0.0509, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 184 loss:   tensor(0.0604, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 185 loss:   tensor(0.0737, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 186 loss:   tensor(0.0875, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 187 loss:   tensor(0.0355, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 188 loss:   tensor(0.0603, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 189 loss:   tensor(0.0405, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 190 loss:   tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 190 :
# AUC:0.9460   accuracy:88.7336%
# epoch 191 loss:   tensor(0.1210, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 192 loss:   tensor(0.1585, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 193 loss:   tensor(0.0267, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 194 loss:   tensor(0.0793, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 195 loss:   tensor(0.1177, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 196 loss:   tensor(0.0258, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 197 loss:   tensor(0.0829, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 198 loss:   tensor(0.0713, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 199 loss:   tensor(0.0799, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 200 loss:   tensor(0.0666, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 200 :
# AUC:0.9425   accuracy:86.0262%
# epoch 201 loss:   tensor(0.0735, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 202 loss:   tensor(0.0861, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 203 loss:   tensor(0.0807, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 204 loss:   tensor(0.0456, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 205 loss:   tensor(0.0282, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 206 loss:   tensor(0.1481, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 207 loss:   tensor(0.0547, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 208 loss:   tensor(0.0593, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 209 loss:   tensor(0.0414, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 210 loss:   tensor(0.1377, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 210 :
# AUC:0.9500   accuracy:88.3843%
# epoch 211 loss:   tensor(0.0319, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 212 loss:   tensor(0.0708, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 213 loss:   tensor(0.0620, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 214 loss:   tensor(0.0691, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 215 loss:   tensor(0.0677, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 216 loss:   tensor(0.0420, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 217 loss:   tensor(0.0558, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 218 loss:   tensor(0.0524, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 219 loss:   tensor(0.0463, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 220 loss:   tensor(0.0777, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 220 :
# AUC:0.9410   accuracy:89.4323%
# epoch 221 loss:   tensor(0.0305, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 222 loss:   tensor(0.0814, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 223 loss:   tensor(0.0571, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 224 loss:   tensor(0.0535, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 225 loss:   tensor(0.0907, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 226 loss:   tensor(0.0199, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 227 loss:   tensor(0.0758, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 228 loss:   tensor(0.0729, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 229 loss:   tensor(0.0730, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 230 loss:   tensor(0.0380, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 230 :
# AUC:0.9469   accuracy:87.5983%
# epoch 231 loss:   tensor(0.0619, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 232 loss:   tensor(0.0569, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 233 loss:   tensor(0.0611, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 234 loss:   tensor(0.0755, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 235 loss:   tensor(0.0492, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 236 loss:   tensor(0.0211, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 237 loss:   tensor(0.1197, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 238 loss:   tensor(0.0130, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 239 loss:   tensor(0.0106, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 240 loss:   tensor(0.1871, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 240 :
# AUC:0.9539   accuracy:88.9083%
# epoch 241 loss:   tensor(0.0339, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 242 loss:   tensor(0.0490, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 243 loss:   tensor(0.0616, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 244 loss:   tensor(0.0676, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 245 loss:   tensor(0.0289, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 246 loss:   tensor(0.0900, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 247 loss:   tensor(0.0482, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 248 loss:   tensor(0.0480, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 249 loss:   tensor(0.0751, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 250 loss:   tensor(0.0497, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 250 :
# AUC:0.9499   accuracy:89.1703%
# epoch 251 loss:   tensor(0.0428, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 252 loss:   tensor(0.0528, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 253 loss:   tensor(0.0442, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 254 loss:   tensor(0.0909, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 255 loss:   tensor(0.0669, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 256 loss:   tensor(0.0261, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 257 loss:   tensor(0.0333, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 258 loss:   tensor(0.0667, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 259 loss:   tensor(0.0473, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 260 loss:   tensor(0.0850, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 260 :
# AUC:0.9538   accuracy:89.0830%
# epoch 261 loss:   tensor(0.0422, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 262 loss:   tensor(0.0520, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 263 loss:   tensor(0.0183, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 264 loss:   tensor(0.0635, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 265 loss:   tensor(0.0594, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 266 loss:   tensor(0.0201, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 267 loss:   tensor(0.0789, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 268 loss:   tensor(0.0689, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 269 loss:   tensor(0.0175, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 270 loss:   tensor(0.0186, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 270 :
# AUC:0.9487   accuracy:88.8210%
# epoch 271 loss:   tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 272 loss:   tensor(0.1771, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 273 loss:   tensor(0.0317, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 274 loss:   tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 275 loss:   tensor(0.0912, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 276 loss:   tensor(0.0561, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 277 loss:   tensor(0.0426, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 278 loss:   tensor(0.0444, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 279 loss:   tensor(0.0327, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 280 loss:   tensor(0.0366, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 280 :
# AUC:0.9522   accuracy:88.5590%
# epoch 281 loss:   tensor(0.0652, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 282 loss:   tensor(0.0477, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 283 loss:   tensor(0.0213, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 284 loss:   tensor(0.1004, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 285 loss:   tensor(0.0304, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 286 loss:   tensor(0.0463, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 287 loss:   tensor(0.0586, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 288 loss:   tensor(0.0282, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 289 loss:   tensor(0.0379, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 290 loss:   tensor(0.0580, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 290 :
# AUC:0.9433   accuracy:87.0742%
# epoch 291 loss:   tensor(0.0312, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 292 loss:   tensor(0.0591, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 293 loss:   tensor(0.0439, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 294 loss:   tensor(0.0326, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 295 loss:   tensor(0.0312, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 296 loss:   tensor(0.0619, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 297 loss:   tensor(0.0496, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 298 loss:   tensor(0.0455, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 299 loss:   tensor(0.0228, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 300 loss:   tensor(0.0723, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 300 :
# AUC:0.9472   accuracy:89.6070%

# %%
device=torch.device('cuda:0')
model=Nano(c_s=4,c_x=3,c_emb=96,c_f=16,c_hidden_att=64,c_o=1,no_heads=8,blocks_lis=[0,0,0,0,0,0],
            row_dropout=0.1,col_dropout=0.1,transition_n=2,inf=1e9,eps=1e-8,
            clear_cache_between_blocks=False).to(device)
optimizer=optim.Adam(model.parameters(),lr=0.0001)
loss_func=nn.BCELoss().to(device)
epochs=300
train(model,m5C_Nano_train_loader,m5C_Nano_test_loader,device,optimizer,loss_func,epochs,0,0)
# Out:
# epoch 1 loss:   tensor(2.6367, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 2 loss:   tensor(2.2904, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 3 loss:   tensor(2.1701, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 4 loss:   tensor(2.0917, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 5 loss:   tensor(2.0328, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 6 loss:   tensor(1.9862, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 7 loss:   tensor(1.9472, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 8 loss:   tensor(1.8974, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 9 loss:   tensor(1.8830, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 10 loss:   tensor(1.8274, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 10 :
# AUC:0.8521   accuracy:78.3406%
# epoch 11 loss:   tensor(1.7943, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 12 loss:   tensor(1.7644, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 13 loss:   tensor(1.7048, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 14 loss:   tensor(1.6543, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 15 loss:   tensor(1.5806, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 16 loss:   tensor(1.5380, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 17 loss:   tensor(1.4472, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 18 loss:   tensor(1.4031, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 19 loss:   tensor(1.3158, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 20 loss:   tensor(1.2811, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 20 :
# AUC:0.9002   accuracy:82.5328%
# epoch 21 loss:   tensor(1.2190, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 22 loss:   tensor(1.1210, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 23 loss:   tensor(1.0934, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 24 loss:   tensor(1.0427, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 25 loss:   tensor(0.9796, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 26 loss:   tensor(0.9095, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 27 loss:   tensor(0.8564, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 28 loss:   tensor(0.7668, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 29 loss:   tensor(0.7531, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 30 loss:   tensor(0.7230, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 30 :
# AUC:0.9183   accuracy:85.9389%
# epoch 31 loss:   tensor(0.6419, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 32 loss:   tensor(0.6093, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 33 loss:   tensor(0.5434, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 34 loss:   tensor(0.5132, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 35 loss:   tensor(0.4666, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 36 loss:   tensor(0.4583, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 37 loss:   tensor(0.4243, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 38 loss:   tensor(0.3852, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 39 loss:   tensor(0.3322, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 40 loss:   tensor(0.3489, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 40 :
# AUC:0.9325   accuracy:87.5109%
# epoch 41 loss:   tensor(0.2799, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 42 loss:   tensor(0.2683, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 43 loss:   tensor(0.3128, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 44 loss:   tensor(0.2763, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 45 loss:   tensor(0.2463, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 46 loss:   tensor(0.2678, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 47 loss:   tensor(0.1672, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 48 loss:   tensor(0.2430, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 49 loss:   tensor(0.2112, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 50 loss:   tensor(0.1712, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 50 :
# AUC:0.9348   accuracy:87.4236%
# epoch 51 loss:   tensor(0.2392, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 52 loss:   tensor(0.1854, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 53 loss:   tensor(0.2050, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 54 loss:   tensor(0.1808, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 55 loss:   tensor(0.1827, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 56 loss:   tensor(0.1207, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 57 loss:   tensor(0.2131, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 58 loss:   tensor(0.1355, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 59 loss:   tensor(0.1073, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 60 loss:   tensor(0.1996, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 60 :
# AUC:0.9297   accuracy:88.2096%
# epoch 61 loss:   tensor(0.1608, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 62 loss:   tensor(0.1623, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 63 loss:   tensor(0.1270, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 64 loss:   tensor(0.1415, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 65 loss:   tensor(0.1135, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 66 loss:   tensor(0.1098, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 67 loss:   tensor(0.1186, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 68 loss:   tensor(0.1500, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 69 loss:   tensor(0.1169, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 70 loss:   tensor(0.1028, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 70 :
# AUC:0.9378   accuracy:87.5109%
# epoch 71 loss:   tensor(0.1290, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 72 loss:   tensor(0.0934, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 73 loss:   tensor(0.1179, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 74 loss:   tensor(0.0950, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 75 loss:   tensor(0.1213, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 76 loss:   tensor(0.1151, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 77 loss:   tensor(0.0904, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 78 loss:   tensor(0.0758, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 79 loss:   tensor(0.1058, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 80 loss:   tensor(0.1160, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 80 :
# AUC:0.9376   accuracy:88.9083%
# epoch 81 loss:   tensor(0.0767, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 82 loss:   tensor(0.0770, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 83 loss:   tensor(0.1379, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 84 loss:   tensor(0.0509, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 85 loss:   tensor(0.1008, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 86 loss:   tensor(0.1000, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 87 loss:   tensor(0.0957, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 88 loss:   tensor(0.0847, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 89 loss:   tensor(0.0973, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 90 loss:   tensor(0.0986, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 90 :
# AUC:0.9439   accuracy:88.0349%
# epoch 91 loss:   tensor(0.0474, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 92 loss:   tensor(0.1100, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 93 loss:   tensor(0.0796, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 94 loss:   tensor(0.1067, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 95 loss:   tensor(0.0513, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 96 loss:   tensor(0.0833, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 97 loss:   tensor(0.0914, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 98 loss:   tensor(0.1280, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 99 loss:   tensor(0.0295, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 100 loss:   tensor(0.1118, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 100 :
# AUC:0.9374   accuracy:87.4236%
# epoch 101 loss:   tensor(0.0738, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 102 loss:   tensor(0.0420, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 103 loss:   tensor(0.0886, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 104 loss:   tensor(0.0529, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 105 loss:   tensor(0.1011, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 106 loss:   tensor(0.0557, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 107 loss:   tensor(0.0845, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 108 loss:   tensor(0.0647, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 109 loss:   tensor(0.0844, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 110 loss:   tensor(0.0433, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 110 :
# AUC:0.9418   accuracy:89.1703%
# epoch 111 loss:   tensor(0.0765, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 112 loss:   tensor(0.0967, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 113 loss:   tensor(0.0369, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 114 loss:   tensor(0.0778, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 115 loss:   tensor(0.0638, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 116 loss:   tensor(0.0486, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 117 loss:   tensor(0.0307, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 118 loss:   tensor(0.1087, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 119 loss:   tensor(0.0295, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 120 loss:   tensor(0.0639, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 120 :
# AUC:0.9421   accuracy:86.7249%
# epoch 121 loss:   tensor(0.0530, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 122 loss:   tensor(0.1052, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 123 loss:   tensor(0.0432, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 124 loss:   tensor(0.0425, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 125 loss:   tensor(0.0653, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 126 loss:   tensor(0.0750, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 127 loss:   tensor(0.0764, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 128 loss:   tensor(0.0525, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 129 loss:   tensor(0.0216, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 130 loss:   tensor(0.0855, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 130 :
# AUC:0.9472   accuracy:87.2489%
# epoch 131 loss:   tensor(0.0486, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 132 loss:   tensor(0.0486, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 133 loss:   tensor(0.0917, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 134 loss:   tensor(0.0453, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 135 loss:   tensor(0.0434, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 136 loss:   tensor(0.0811, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 137 loss:   tensor(0.0485, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 138 loss:   tensor(0.0545, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 139 loss:   tensor(0.0437, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 140 loss:   tensor(0.0796, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 140 :
# AUC:0.9367   accuracy:87.5983%
# epoch 141 loss:   tensor(0.0645, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 142 loss:   tensor(0.0103, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 143 loss:   tensor(0.0553, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 144 loss:   tensor(0.0564, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 145 loss:   tensor(0.0540, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 146 loss:   tensor(0.0640, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 147 loss:   tensor(0.0364, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 148 loss:   tensor(0.0419, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 149 loss:   tensor(0.0491, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 150 loss:   tensor(0.0343, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 150 :
# AUC:0.9532   accuracy:88.8210%
# epoch 151 loss:   tensor(0.0198, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 152 loss:   tensor(0.0915, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 153 loss:   tensor(0.0364, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 154 loss:   tensor(0.0477, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 155 loss:   tensor(0.0430, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 156 loss:   tensor(0.0517, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 157 loss:   tensor(0.0157, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 158 loss:   tensor(0.0702, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 159 loss:   tensor(0.0091, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 160 loss:   tensor(0.0747, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 160 :
# AUC:0.9453   accuracy:89.9563%
# epoch 161 loss:   tensor(0.0101, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 162 loss:   tensor(0.0739, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 163 loss:   tensor(0.0317, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 164 loss:   tensor(0.0578, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 165 loss:   tensor(0.0273, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 166 loss:   tensor(0.0732, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 167 loss:   tensor(0.0360, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 168 loss:   tensor(0.0394, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 169 loss:   tensor(0.0435, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 170 loss:   tensor(0.0297, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 170 :
# AUC:0.9526   accuracy:89.0830%
# epoch 171 loss:   tensor(0.0670, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 172 loss:   tensor(0.0305, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 173 loss:   tensor(0.0234, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 174 loss:   tensor(0.0808, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 175 loss:   tensor(0.0374, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 176 loss:   tensor(0.0724, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 177 loss:   tensor(0.0179, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 178 loss:   tensor(0.0360, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 179 loss:   tensor(0.0368, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 180 loss:   tensor(0.0601, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 180 :
# AUC:0.9417   accuracy:87.6856%
# epoch 181 loss:   tensor(0.0420, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 182 loss:   tensor(0.0393, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 183 loss:   tensor(0.0602, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 184 loss:   tensor(0.0323, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 185 loss:   tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 186 loss:   tensor(0.0614, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 187 loss:   tensor(0.0311, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 188 loss:   tensor(0.0506, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 189 loss:   tensor(0.0162, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 190 loss:   tensor(0.0435, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 190 :
# AUC:0.9580   accuracy:90.1310%
# epoch 191 loss:   tensor(0.0200, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 192 loss:   tensor(0.0680, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 193 loss:   tensor(0.0333, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 194 loss:   tensor(0.0401, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 195 loss:   tensor(0.0446, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 196 loss:   tensor(0.0192, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 197 loss:   tensor(0.0646, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 198 loss:   tensor(0.0305, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 199 loss:   tensor(0.0221, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 200 loss:   tensor(0.0281, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 200 :
# AUC:0.9421   accuracy:86.4629%
# epoch 201 loss:   tensor(0.0383, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 202 loss:   tensor(0.0373, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 203 loss:   tensor(0.0311, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 204 loss:   tensor(0.0330, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 205 loss:   tensor(0.0348, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 206 loss:   tensor(0.0534, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 207 loss:   tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 208 loss:   tensor(0.0518, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 209 loss:   tensor(0.0238, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 210 loss:   tensor(0.0387, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 210 :
# AUC:0.9517   accuracy:89.1703%
# epoch 211 loss:   tensor(0.0234, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 212 loss:   tensor(0.0334, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 213 loss:   tensor(0.0322, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 214 loss:   tensor(0.0079, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 215 loss:   tensor(0.0515, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 216 loss:   tensor(0.0153, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 217 loss:   tensor(0.0589, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 218 loss:   tensor(0.0330, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 219 loss:   tensor(0.0290, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 220 loss:   tensor(0.0493, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 220 :
# AUC:0.9508   accuracy:89.0830%
# epoch 221 loss:   tensor(0.0173, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 222 loss:   tensor(0.0387, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 223 loss:   tensor(0.0449, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 224 loss:   tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 225 loss:   tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 226 loss:   tensor(0.0608, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 227 loss:   tensor(0.0338, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 228 loss:   tensor(0.0340, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 229 loss:   tensor(0.0378, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 230 loss:   tensor(0.0260, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 230 :
# AUC:0.9550   accuracy:89.5197%
# epoch 231 loss:   tensor(0.0079, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 232 loss:   tensor(0.0255, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 233 loss:   tensor(0.0278, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 234 loss:   tensor(0.0498, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 235 loss:   tensor(0.0339, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 236 loss:   tensor(0.0625, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 237 loss:   tensor(0.0292, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 238 loss:   tensor(0.0296, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 239 loss:   tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 240 loss:   tensor(0.0316, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 240 :
# AUC:0.9467   accuracy:88.8210%
# epoch 241 loss:   tensor(0.0490, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 242 loss:   tensor(0.0352, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 243 loss:   tensor(0.0264, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 244 loss:   tensor(0.0106, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 245 loss:   tensor(0.0396, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 246 loss:   tensor(0.0350, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 247 loss:   tensor(0.0064, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 248 loss:   tensor(0.0263, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 249 loss:   tensor(0.0337, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 250 loss:   tensor(0.0213, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 250 :
# AUC:0.9443   accuracy:87.5983%
# epoch 251 loss:   tensor(0.0472, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 252 loss:   tensor(0.0118, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 253 loss:   tensor(0.0278, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 254 loss:   tensor(0.0247, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 255 loss:   tensor(0.0069, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 256 loss:   tensor(0.0515, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 257 loss:   tensor(0.0327, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 258 loss:   tensor(0.0190, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 259 loss:   tensor(0.0286, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 260 loss:   tensor(0.0451, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 260 :
# AUC:0.9548   accuracy:90.1310%
# epoch 261 loss:   tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 262 loss:   tensor(0.0069, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 263 loss:   tensor(0.0535, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 264 loss:   tensor(0.0430, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 265 loss:   tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 266 loss:   tensor(0.0251, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 267 loss:   tensor(0.0148, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 268 loss:   tensor(0.0210, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 269 loss:   tensor(0.0549, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 270 loss:   tensor(0.0327, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 270 :
# AUC:0.9485   accuracy:88.2969%
# epoch 271 loss:   tensor(0.0191, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 272 loss:   tensor(0.0503, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 273 loss:   tensor(0.0162, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 274 loss:   tensor(0.0485, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 275 loss:   tensor(0.0191, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 276 loss:   tensor(0.0112, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 277 loss:   tensor(0.0095, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 278 loss:   tensor(0.0389, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 279 loss:   tensor(0.0547, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 280 loss:   tensor(0.0074, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 280 :
# AUC:0.9521   accuracy:89.5197%
# epoch 281 loss:   tensor(0.0374, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 282 loss:   tensor(0.0094, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 283 loss:   tensor(0.0475, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 284 loss:   tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 285 loss:   tensor(0.0369, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 286 loss:   tensor(0.0258, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 287 loss:   tensor(0.0168, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 288 loss:   tensor(0.0667, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 289 loss:   tensor(0.0373, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 290 loss:   tensor(0.0315, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 290 :
# AUC:0.9492   accuracy:89.5197%
# epoch 291 loss:   tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 292 loss:   tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 293 loss:   tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 294 loss:   tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 295 loss:   tensor(2.1471e-05, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 296 loss:   tensor(0.0752, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 297 loss:   tensor(0.0362, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 298 loss:   tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 299 loss:   tensor(0.0225, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 300 loss:   tensor(0.0200, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 300 :
# AUC:0.9480   accuracy:88.9956%

# %%
#20 reads 3 sites
device=torch.device('cuda:0')
model=Nano(c_s=4,c_x=3,c_emb=96,c_f=16,c_hidden_att=64,c_o=1,no_heads=8,blocks_lis=[2,2,2,0,0,0],
            row_dropout=0.1,col_dropout=0.1,transition_n=2,inf=1e9,eps=1e-8,
            clear_cache_between_blocks=False).to(device)
optimizer=optim.Adam(model.parameters(),lr=0.0001)
loss_func=nn.BCELoss().to(device)
epochs=300
seq_reduce=22
reads_reduce=30
train(model,m5C_Nano_train_loader,m5C_Nano_test_loader,device,optimizer,loss_func,epochs,seq_reduce,reads_reduce)
# Out:
# epoch 1 loss:   tensor(2.7702, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 2 loss:   tensor(2.7000, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 3 loss:   tensor(2.6918, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 4 loss:   tensor(2.6882, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 5 loss:   tensor(2.6867, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 6 loss:   tensor(2.6865, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 7 loss:   tensor(2.6850, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 8 loss:   tensor(2.6841, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 9 loss:   tensor(2.6835, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 10 loss:   tensor(2.6852, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 10 :
# AUC:0.5963   accuracy:57.0306%
# epoch 11 loss:   tensor(2.6846, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 12 loss:   tensor(2.6950, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 13 loss:   tensor(2.6963, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 14 loss:   tensor(2.6830, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 15 loss:   tensor(2.6774, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 16 loss:   tensor(2.6774, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 17 loss:   tensor(2.6788, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 18 loss:   tensor(2.6844, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 19 loss:   tensor(2.6790, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 20 loss:   tensor(2.6839, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 20 :
# AUC:0.5944   accuracy:57.2926%
# epoch 21 loss:   tensor(2.6708, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 22 loss:   tensor(2.6748, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 23 loss:   tensor(2.6538, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 24 loss:   tensor(2.6520, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 25 loss:   tensor(2.6348, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 26 loss:   tensor(2.6273, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 27 loss:   tensor(2.6268, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 28 loss:   tensor(2.6255, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 29 loss:   tensor(2.6192, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 30 loss:   tensor(2.6034, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 30 :
# AUC:0.6227   accuracy:59.0393%
# epoch 31 loss:   tensor(2.5935, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 32 loss:   tensor(2.5826, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 33 loss:   tensor(2.5868, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 34 loss:   tensor(2.5792, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 35 loss:   tensor(2.5699, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 36 loss:   tensor(2.5793, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 37 loss:   tensor(2.5700, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 38 loss:   tensor(2.5655, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 39 loss:   tensor(2.5713, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 40 loss:   tensor(2.5536, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 40 :
# AUC:0.6352   accuracy:61.3974%
# epoch 41 loss:   tensor(2.5523, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 42 loss:   tensor(2.5631, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 43 loss:   tensor(2.5502, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 44 loss:   tensor(2.5377, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 45 loss:   tensor(2.5409, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 46 loss:   tensor(2.5451, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 47 loss:   tensor(2.5218, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 48 loss:   tensor(2.5306, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 49 loss:   tensor(2.5324, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 50 loss:   tensor(2.5260, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 50 :
# AUC:0.6550   accuracy:61.6594%
# epoch 51 loss:   tensor(2.5229, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 52 loss:   tensor(2.5286, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 53 loss:   tensor(2.5224, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 54 loss:   tensor(2.5274, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 55 loss:   tensor(2.5176, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 56 loss:   tensor(2.5179, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 57 loss:   tensor(2.5126, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 58 loss:   tensor(2.5131, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 59 loss:   tensor(2.5055, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 60 loss:   tensor(2.5051, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 60 :
# AUC:0.6570   accuracy:63.1441%
# epoch 61 loss:   tensor(2.4951, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 62 loss:   tensor(2.5066, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 63 loss:   tensor(2.4867, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 64 loss:   tensor(2.4976, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 65 loss:   tensor(2.4987, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 66 loss:   tensor(2.5146, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 67 loss:   tensor(2.4992, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 68 loss:   tensor(2.4840, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 69 loss:   tensor(2.4760, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 70 loss:   tensor(2.4722, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 70 :
# AUC:0.6711   accuracy:64.2795%
# epoch 71 loss:   tensor(2.4780, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 72 loss:   tensor(2.4751, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 73 loss:   tensor(2.4574, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 74 loss:   tensor(2.4593, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 75 loss:   tensor(2.4466, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 76 loss:   tensor(2.4682, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 77 loss:   tensor(2.4518, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 78 loss:   tensor(2.4495, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 79 loss:   tensor(2.4471, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 80 loss:   tensor(2.4521, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 80 :
# AUC:0.6735   accuracy:62.5328%
# epoch 81 loss:   tensor(2.4429, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 82 loss:   tensor(2.4852, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 83 loss:   tensor(2.4699, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 84 loss:   tensor(2.4454, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 85 loss:   tensor(2.4255, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 86 loss:   tensor(2.4373, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 87 loss:   tensor(2.4366, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 88 loss:   tensor(2.4419, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 89 loss:   tensor(2.4077, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 90 loss:   tensor(2.4236, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 90 :
# AUC:0.6923   accuracy:66.2882%
# epoch 91 loss:   tensor(2.4117, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 92 loss:   tensor(2.3985, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 93 loss:   tensor(2.3990, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 94 loss:   tensor(2.4044, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 95 loss:   tensor(2.3950, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 96 loss:   tensor(2.3907, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 97 loss:   tensor(2.3830, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 98 loss:   tensor(2.3943, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 99 loss:   tensor(2.3903, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 100 loss:   tensor(2.3651, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 100 :
# AUC:0.6890   accuracy:65.8515%
# epoch 101 loss:   tensor(2.3602, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 102 loss:   tensor(2.3750, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 103 loss:   tensor(2.3423, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 104 loss:   tensor(2.3517, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 105 loss:   tensor(2.3515, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 106 loss:   tensor(2.3296, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 107 loss:   tensor(2.3663, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 108 loss:   tensor(2.3679, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 109 loss:   tensor(2.3599, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 110 loss:   tensor(2.3458, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 110 :
# AUC:0.6923   accuracy:64.6288%
# epoch 111 loss:   tensor(2.3371, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 112 loss:   tensor(2.3234, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 113 loss:   tensor(2.3154, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 114 loss:   tensor(2.3132, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 115 loss:   tensor(2.3179, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 116 loss:   tensor(2.3221, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 117 loss:   tensor(2.3052, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 118 loss:   tensor(2.3044, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 119 loss:   tensor(2.2921, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 120 loss:   tensor(2.2785, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 120 :
# AUC:0.7007   accuracy:64.8908%
# epoch 121 loss:   tensor(2.2862, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 122 loss:   tensor(2.2695, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 123 loss:   tensor(2.2495, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 124 loss:   tensor(2.2484, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 125 loss:   tensor(2.2461, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 126 loss:   tensor(2.2400, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 127 loss:   tensor(2.2373, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 128 loss:   tensor(2.2240, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 129 loss:   tensor(2.2166, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 130 loss:   tensor(2.1946, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 130 :
# AUC:0.7018   accuracy:66.1135%
# epoch 131 loss:   tensor(2.2218, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 132 loss:   tensor(2.2097, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 133 loss:   tensor(2.1789, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 134 loss:   tensor(2.2105, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 135 loss:   tensor(2.1750, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 136 loss:   tensor(2.1741, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 137 loss:   tensor(2.1660, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 138 loss:   tensor(2.1465, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 139 loss:   tensor(2.1459, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 140 loss:   tensor(2.1486, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 140 :
# AUC:0.6942   accuracy:64.5415%
# epoch 141 loss:   tensor(2.1685, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 142 loss:   tensor(2.0974, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 143 loss:   tensor(2.0999, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 144 loss:   tensor(2.1156, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 145 loss:   tensor(2.1378, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 146 loss:   tensor(2.1451, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 147 loss:   tensor(2.1091, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 148 loss:   tensor(2.1312, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 149 loss:   tensor(2.1071, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 150 loss:   tensor(2.0897, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 150 :
# AUC:0.6880   accuracy:64.2795%
# epoch 151 loss:   tensor(2.0835, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 152 loss:   tensor(2.0606, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 153 loss:   tensor(2.0353, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 154 loss:   tensor(2.0518, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 155 loss:   tensor(2.0393, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 156 loss:   tensor(2.0161, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 157 loss:   tensor(1.9745, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 158 loss:   tensor(2.0210, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 159 loss:   tensor(1.9878, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 160 loss:   tensor(1.9904, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 160 :
# AUC:0.6933   accuracy:62.8821%
# epoch 161 loss:   tensor(2.0166, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 162 loss:   tensor(1.9893, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 163 loss:   tensor(1.9381, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 164 loss:   tensor(1.9453, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 165 loss:   tensor(1.9393, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 166 loss:   tensor(1.9099, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 167 loss:   tensor(1.9239, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 168 loss:   tensor(1.9079, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 169 loss:   tensor(1.9412, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 170 loss:   tensor(1.8943, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 170 :
# AUC:0.6935   accuracy:64.1921%
# epoch 171 loss:   tensor(1.8913, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 172 loss:   tensor(1.9236, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 173 loss:   tensor(1.8953, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 174 loss:   tensor(1.8710, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 175 loss:   tensor(1.8528, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 176 loss:   tensor(1.8366, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 177 loss:   tensor(1.8412, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 178 loss:   tensor(1.8564, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 179 loss:   tensor(1.8150, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 180 loss:   tensor(1.8166, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 180 :
# AUC:0.6988   accuracy:64.0175%
# epoch 181 loss:   tensor(1.8188, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 182 loss:   tensor(1.8582, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 183 loss:   tensor(1.7640, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 184 loss:   tensor(1.7523, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 185 loss:   tensor(1.8061, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 186 loss:   tensor(1.7757, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 187 loss:   tensor(1.7745, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 188 loss:   tensor(1.7313, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 189 loss:   tensor(1.7031, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 190 loss:   tensor(1.7539, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 190 :
# AUC:0.6872   accuracy:64.3668%
# epoch 191 loss:   tensor(1.6390, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 192 loss:   tensor(1.7126, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 193 loss:   tensor(1.6995, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 194 loss:   tensor(1.6966, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 195 loss:   tensor(1.6797, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 196 loss:   tensor(1.6827, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 197 loss:   tensor(1.6679, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 198 loss:   tensor(1.6289, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 199 loss:   tensor(1.7039, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 200 loss:   tensor(1.6646, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 200 :
# AUC:0.6780   accuracy:62.1834%
# epoch 201 loss:   tensor(1.5867, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 202 loss:   tensor(1.6000, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 203 loss:   tensor(1.6290, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 204 loss:   tensor(1.5815, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 205 loss:   tensor(1.5149, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 206 loss:   tensor(1.6274, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 207 loss:   tensor(1.5732, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 208 loss:   tensor(1.5651, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 209 loss:   tensor(1.5655, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 210 loss:   tensor(1.6365, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 210 :
# AUC:0.6912   accuracy:64.4542%
# epoch 211 loss:   tensor(1.7713, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 212 loss:   tensor(1.6360, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 213 loss:   tensor(1.6542, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 214 loss:   tensor(1.6325, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 215 loss:   tensor(1.5930, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 216 loss:   tensor(1.5433, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 217 loss:   tensor(1.5234, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 218 loss:   tensor(1.6789, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 219 loss:   tensor(1.5411, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 220 loss:   tensor(1.5354, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 220 :
# AUC:0.6928   accuracy:64.2795%
# epoch 221 loss:   tensor(1.4644, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 222 loss:   tensor(1.4874, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 223 loss:   tensor(1.4355, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 224 loss:   tensor(1.4492, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 225 loss:   tensor(1.4577, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 226 loss:   tensor(1.4504, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 227 loss:   tensor(1.4452, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 228 loss:   tensor(1.3613, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 229 loss:   tensor(1.4393, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 230 loss:   tensor(1.3706, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 230 :
# AUC:0.7086   accuracy:65.1528%
# epoch 231 loss:   tensor(1.3780, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 232 loss:   tensor(1.4157, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 233 loss:   tensor(1.5282, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 234 loss:   tensor(1.5020, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 235 loss:   tensor(1.3820, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 236 loss:   tensor(1.5070, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 237 loss:   tensor(1.4404, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 238 loss:   tensor(1.4034, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 239 loss:   tensor(1.3520, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 240 loss:   tensor(1.4266, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 240 :
# AUC:0.6995   accuracy:65.0655%
# epoch 241 loss:   tensor(1.8325, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 242 loss:   tensor(1.7275, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 243 loss:   tensor(1.5620, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 244 loss:   tensor(1.5180, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 245 loss:   tensor(1.4630, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 246 loss:   tensor(1.5143, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 247 loss:   tensor(1.6136, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 248 loss:   tensor(1.4666, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 249 loss:   tensor(1.4586, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 250 loss:   tensor(1.3874, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 250 :
# AUC:0.7073   accuracy:65.9389%
# epoch 251 loss:   tensor(1.3159, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 252 loss:   tensor(1.2967, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 253 loss:   tensor(1.2616, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 254 loss:   tensor(1.3044, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 255 loss:   tensor(1.2884, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 256 loss:   tensor(1.6160, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 257 loss:   tensor(1.5276, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 258 loss:   tensor(1.4171, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 259 loss:   tensor(1.3294, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 260 loss:   tensor(1.3010, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 260 :
# AUC:0.7015   accuracy:66.0262%
# epoch 261 loss:   tensor(1.3983, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 262 loss:   tensor(1.2602, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 263 loss:   tensor(1.2454, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 264 loss:   tensor(1.2485, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 265 loss:   tensor(1.1975, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 266 loss:   tensor(1.2003, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 267 loss:   tensor(1.3895, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 268 loss:   tensor(1.4672, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 269 loss:   tensor(1.3000, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 270 loss:   tensor(1.2058, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 270 :
# AUC:0.7048   accuracy:66.1135%
# epoch 271 loss:   tensor(1.8485, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 272 loss:   tensor(2.4214, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 273 loss:   tensor(1.9781, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 274 loss:   tensor(1.5947, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 275 loss:   tensor(1.6155, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 276 loss:   tensor(1.5286, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 277 loss:   tensor(1.3778, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 278 loss:   tensor(1.5401, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 279 loss:   tensor(1.9834, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 280 loss:   tensor(1.5688, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 280 :
# AUC:0.6802   accuracy:62.9694%
# epoch 281 loss:   tensor(1.4382, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 282 loss:   tensor(1.4681, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 283 loss:   tensor(1.5621, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 284 loss:   tensor(1.5219, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 285 loss:   tensor(1.6373, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 286 loss:   tensor(1.8733, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 287 loss:   tensor(1.4743, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 288 loss:   tensor(1.4770, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 289 loss:   tensor(1.4272, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 290 loss:   tensor(1.3567, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 290 :
# AUC:0.6947   accuracy:64.4542%
# epoch 291 loss:   tensor(1.2291, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 292 loss:   tensor(1.2684, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 293 loss:   tensor(1.2649, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 294 loss:   tensor(1.3494, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 295 loss:   tensor(1.3707, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 296 loss:   tensor(1.2038, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 297 loss:   tensor(1.1708, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 298 loss:   tensor(1.1897, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 299 loss:   tensor(1.2341, device='cuda:0', grad_fn=<DivBackward0>)
# epoch 300 loss:   tensor(1.1798, device='cuda:0', grad_fn=<DivBackward0>)
# At epoch 300 :
# AUC:0.7156   accuracy:66.2009%

# %% [markdown]
# # Test

# %%
device=torch.device('cuda:0')
model=Nano(c_s=4,c_x=3,c_emb=96,c_f=16,c_hidden_att=64,c_o=1,no_heads=8,blocks_lis=[2,2,2,0,0,0],
            row_dropout=0.1,col_dropout=0.1,transition_n=2,inf=1e9,eps=1e-8,
            clear_cache_between_blocks=False).to(device)
#model.load_state_dict(torch.load('./model/m5C_NSWord_keep_model_290_222000.pkl'))
model.load_state_dict(torch.load('./model/m5C_NSWord_keep_model_260_222000.pkl'))
detailed_test(model,m5C_Nano_test_loader,device,0,0,'m5C_Blocks=[222000],50reads_25sites')
# Out:
# Im total 1145 samples:
# AUC:0.9516   accuracy:88.6463%
# Precision when positive threshold at 0.5 is :0.8506% (total:629)
# Precision when positive threshold at 0.6 is :0.8583% (total:621)
# Precision when positive threshold at 0.8 is :0.8699% (total:607)
# Precision when positive threshold at 0.7 is :0.8648% (total:614)
# Precision when positive threshold at 0.9 is :0.8832% (total:591)
# Precision when positive threshold at 0.95 is :0.8948% (total:580)
# Precision when positive threshold at 0.98 is :0.8989% (total:564)
# Precision when positive threshold at 0.99 is :0.9091% (total:550)
# Precision when positive threshold at 0.995 is :0.9148% (total:540)
# Precision when positive threshold at 0.999 is :0.9327% (total:505)
# Precision when positive threshold at 0.9995 is :0.9389% (total:491)
# Precision when positive threshold at 0.9999 is :0.9427% (total:454)
# Precision when positive threshold at 0.99995 is :0.9497% (total:437)
# Precision when positive threshold at 0.99999 is :0.9509% (total:407)
# Precision when positive threshold at 0.999995 is :0.9509% (total:387)
# Precision when positive threshold at 0.999999 is :0.9509% (total:346)

# %%
device=torch.device('cuda:0')
model=Nano(c_s=4,c_x=3,c_emb=96,c_f=16,c_hidden_att=64,c_o=1,no_heads=8,blocks_lis=[2,2,0,0,1,1],
            row_dropout=0.1,col_dropout=0.1,transition_n=2,inf=1e9,eps=1e-8,
            clear_cache_between_blocks=False).to(device)
#model.load_state_dict(torch.load('./model/m5C_NSWord_keep_model_260_2200011.pkl'))
model.load_state_dict(torch.load('./model/m5C_NSWord_keep_model_240_220011.pkl'))
detailed_test(model,m5C_Nano_test_loader,device,0,0,'m5C_Blocks=[220011],50reads_25sites')
# Out:
# Im total 1145 samples:
# AUC:0.9539   accuracy:88.9083%
# Precision when positive threshold at 0.5 is :0.8663% (total:606)
# Precision when positive threshold at 0.6 is :0.8659% (total:604)
# Precision when positive threshold at 0.8 is :0.8857% (total:586)
# Precision when positive threshold at 0.7 is :0.8717% (total:600)
# Precision when positive threshold at 0.9 is :0.8995% (total:567)
# Precision when positive threshold at 0.95 is :0.9035% (total:549)
# Precision when positive threshold at 0.98 is :0.9173% (total:520)
# Precision when positive threshold at 0.99 is :0.9246% (total:491)
# Precision when positive threshold at 0.995 is :0.9374% (total:463)
# Precision when positive threshold at 0.999 is :0.9586% (total:411)
# Precision when positive threshold at 0.9995 is :0.9635% (total:384)
# Precision when positive threshold at 0.9999 is :0.9643% (total:308)
# Precision when positive threshold at 0.99995 is :0.9725% (total:291)
# Precision when positive threshold at 0.99999 is :0.9716% (total:211)
# Precision when positive threshold at 0.999995 is :0.9778% (total:180)
# Precision when positive threshold at 0.999999 is :1.0000% (total:116)

# %%
device=torch.device('cuda:0')
model=Nano(c_s=4,c_x=3,c_emb=96,c_f=16,c_hidden_att=64,c_o=1,no_heads=8,blocks_lis=[0,0,0,0,0,0],
            row_dropout=0.1,col_dropout=0.1,transition_n=2,inf=1e9,eps=1e-8,
            clear_cache_between_blocks=False).to(device)
#model.load_state_dict(torch.load('./model/m5C_NSWord_keep_model_190_000000.pkl'))
model.load_state_dict(torch.load('./model/m5C_NSWord_keep_model_150_000000.pkl'))
detailed_test(model,m5C_Nano_test_loader,device,0,0,'m5C_Blocks=[000000],50reads_25sites')
# Out:
# Im total 1145 samples:
# AUC:0.9532   accuracy:88.8210%
# Precision when positive threshold at 0.5 is :0.8649% (total:607)
# Precision when positive threshold at 0.6 is :0.8690% (total:603)
# Precision when positive threshold at 0.8 is :0.8788% (total:594)
# Precision when positive threshold at 0.7 is :0.8719% (total:601)
# Precision when positive threshold at 0.9 is :0.8855% (total:585)
# Precision when positive threshold at 0.95 is :0.8866% (total:582)
# Precision when positive threshold at 0.98 is :0.8996% (total:568)
# Precision when positive threshold at 0.99 is :0.9055% (total:561)
# Precision when positive threshold at 0.995 is :0.9116% (total:554)
# Precision when positive threshold at 0.999 is :0.9244% (total:529)
# Precision when positive threshold at 0.9995 is :0.9290% (total:521)
# Precision when positive threshold at 0.9999 is :0.9413% (total:494)
# Precision when positive threshold at 0.99995 is :0.9424% (total:486)
# Precision when positive threshold at 0.99999 is :0.9539% (total:434)
# Precision when positive threshold at 0.999995 is :0.9540% (total:413)
# Precision when positive threshold at 0.999999 is :0.9606% (total:355)

# %%
#20 reads 3 sites
device=torch.device('cuda:0')
model=Nano(c_s=4,c_x=3,c_emb=96,c_f=16,c_hidden_att=64,c_o=1,no_heads=8,blocks_lis=[2,2,2,0,0,0],
            row_dropout=0.1,col_dropout=0.1,transition_n=2,inf=1e9,eps=1e-8,
            clear_cache_between_blocks=False).to(device)
seq_reduce=22
reads_reduce=30
#model.load_state_dict(torch.load('./model/m5C_NSWord_20reads_3sites_keep_model_230_222000.pkl'))
model.load_state_dict(torch.load('./model/m5C_NSWord_20reads_3sites_keep_model_300_222000.pkl'))
detailed_test(model,m5C_Nano_test_loader,device,seq_reduce,reads_reduce,'m5C_Blocks=[222000],20reads_3sites')
# Out:
# Im total 1145 samples:
# AUC:0.7156   accuracy:66.2009%
# Precision when positive threshold at 0.5 is :0.6575% (total:584)
# Precision when positive threshold at 0.6 is :0.6717% (total:530)
# Precision when positive threshold at 0.8 is :0.7026% (total:417)
# Precision when positive threshold at 0.7 is :0.6897% (total:477)
# Precision when positive threshold at 0.9 is :0.7207% (total:358)
# Precision when positive threshold at 0.95 is :0.7451% (total:306)
# Precision when positive threshold at 0.98 is :0.7677% (total:254)
# Precision when positive threshold at 0.99 is :0.7692% (total:221)
# Precision when positive threshold at 0.995 is :0.7865% (total:192)
# Precision when positive threshold at 0.999 is :0.8267% (total:150)
# Precision when positive threshold at 0.9995 is :0.8473% (total:131)
# Precision when positive threshold at 0.9999 is :0.8646% (total:96)
# Precision when positive threshold at 0.99995 is :0.8778% (total:90)
# Precision when positive threshold at 0.99999 is :0.8824% (total:68)
# Precision when positive threshold at 0.999995 is :0.9016% (total:61)
# Precision when positive threshold at 0.999999 is :0.9000% (total:50)
